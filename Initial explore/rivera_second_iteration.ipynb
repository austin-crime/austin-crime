# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

from acquire import *
from prepare import *
from explore import *
from wrangle import *



from sklearn.model_selection import train_test_split

#Settting matplotlib/seaborn defaults
plt.rc('figure', figsize=(16, 8))
plt.rcParams['axes.facecolor'] = 'whitesmoke'
plt.rcParams['axes.axisbelow'] = True
plt.rc('font', size=16)

# %% [markdown]
# ## Acquire Merged Data Frame

# %%
pd.set_option('display.max_columns', None)

# %%
df = wrangle_merged_df()
df.head()
# Out:
# Using cached csv
#                   crime_type family_violence     occurrence_time  \
# 0  ASSAULT ON PUBLIC SERVANT               N 2021-12-31 23:50:00
# 1         ASSAULT BY CONTACT               N 2021-12-31 12:45:00
# 2        ASSAULT WITH INJURY               N 2021-12-31 11:00:00
# 3                      THEFT               N 2021-12-31 02:00:00
# 4         ASSAULT BY CONTACT               N 2021-12-30 08:29:00
#
#   occurrence_date         report_time report_date  \
# 0      2021-12-31 2021-12-31 23:50:00  2021-12-31
# 1      2021-12-31 2022-01-04 17:07:00  2022-01-04
# 2      2021-12-31 2022-01-05 19:17:00  2022-01-05
# 3      2021-12-31 2022-02-01 22:52:00  2022-02-01
# 4      2021-12-30 2021-12-30 08:29:00  2021-12-30
#
#                   location_type             address  zip_code  \
# 0  COMMERCIAL / OFFICE BUILDING    111 CONGRESS AVE   78701.0
# 1               BAR / NIGHTCLUB        78 RAINEY ST   78701.0
# 2              RESIDENCE / HOME        51 RAINEY ST   78701.0
# 3               BAR / NIGHTCLUB        76 RAINEY ST   78701.0
# 4          HOTEL / MOTEL / ETC.  20 N IH 35 SVRD SB   78701.0
#
#    council_district  sector district   latitude  longitude   clearance_status  \
# 0               9.0  GEORGE        3  30.263739 -97.743651  cleared by arrest
# 1               9.0  GEORGE        3  30.259087 -97.738973        not cleared
# 2               9.0  GEORGE        3  30.256806 -97.739177        not cleared
# 3               9.0  GEORGE        3  30.258917 -97.739019        not cleared
# 4               9.0  GEORGE        3  30.253701 -97.737144        not cleared
#
#   clearance_date  cleared   time_to_report  pandemic_lockdown pd_district  \
# 0     2022-01-03     True  0 days 00:00:00              False    GEORGE 3
# 1     2022-02-28    False  4 days 04:22:00              False    GEORGE 3
# 2     2022-01-12    False  5 days 08:17:00              False    GEORGE 3
# 3     2022-03-14    False 32 days 20:52:00              False    GEORGE 3
# 4     2022-01-05    False  0 days 00:00:00              False    GEORGE 3
#
#                                             the_geom  objectid district_name  \
# 0  MULTIPOLYGON (((-97.735827442287 30.264063289,...        39      GEORGE 3
# 1  MULTIPOLYGON (((-97.735827442287 30.264063289,...        39      GEORGE 3
# 2  MULTIPOLYGON (((-97.735827442287 30.264063289,...        39      GEORGE 3
# 3  MULTIPOLYGON (((-97.735827442287 30.264063289,...        39      GEORGE 3
# 4  MULTIPOLYGON (((-97.735827442287 30.264063289,...        39      GEORGE 3
#
#    sort_order  battalion_id  jurisdiction_id     color  code  external_key  \
# 0           1           194               15  16776960  1299          1299
# 1           1           194               15  16776960  1299          1299
# 2           1           194               15  16776960  1299          1299
# 3           1           194               15  16776960  1299          1299
# 4           1           194               15  16776960  1299          1299
#
#   battalion_code sector_name                    input_date  \
# 0             G1      GEORGE  12/22/2014 11:31:16 AM +0000
# 1             G1      GEORGE  12/22/2014 11:31:16 AM +0000
# 2             G1      GEORGE  12/22/2014 11:31:16 AM +0000
# 3             G1      GEORGE  12/22/2014 11:31:16 AM +0000
# 4             G1      GEORGE  12/22/2014 11:31:16 AM +0000
#
#                   modified_date       input_by modified_by bureau_name  \
# 0  03/03/2017 08:32:07 AM +0000  bmartinlimuel      ap7657       NORTH
# 1  03/03/2017 08:32:07 AM +0000  bmartinlimuel      ap7657       NORTH
# 2  03/03/2017 08:32:07 AM +0000  bmartinlimuel      ap7657       NORTH
# 3  03/03/2017 08:32:07 AM +0000  bmartinlimuel      ap7657       NORTH
# 4  03/03/2017 08:32:07 AM +0000  bmartinlimuel      ap7657       NORTH
#
#   patrol_area command_phone_number  primary_key    shape_area  shape_length
# 0        DTAC         512-974-5203           12  8.371570e+06  14491.846845
# 1        DTAC         512-974-5203           12  8.371570e+06  14491.846845
# 2        DTAC         512-974-5203           12  8.371570e+06  14491.846845
# 3        DTAC         512-974-5203           12  8.371570e+06  14491.846845
# 4        DTAC         512-974-5203           12  8.371570e+06  14491.846845

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352931 entries, 0 to 352930
# Data columns (total 41 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   crime_type            352931 non-null  object
#  1   family_violence       352931 non-null  object
#  2   occurrence_time       352931 non-null  datetime64[ns]
#  3   occurrence_date       352931 non-null  datetime64[ns]
#  4   report_time           352931 non-null  datetime64[ns]
#  5   report_date           352931 non-null  datetime64[ns]
#  6   location_type         352931 non-null  object
#  7   address               352931 non-null  object
#  8   zip_code              352931 non-null  float64
#  9   council_district      352931 non-null  float64
#  10  sector                352931 non-null  object
#  11  district              352931 non-null  object
#  12  latitude              352931 non-null  float64
#  13  longitude             352931 non-null  float64
#  14  clearance_status      352931 non-null  object
#  15  clearance_date        352931 non-null  datetime64[ns]
#  16  cleared               352931 non-null  bool
#  17  time_to_report        352931 non-null  timedelta64[ns]
#  18  pandemic_lockdown     352931 non-null  bool
#  19  pd_district           352931 non-null  object
#  20  the_geom              352931 non-null  object
#  21  objectid              352931 non-null  int64
#  22  district_name         352931 non-null  object
#  23  sort_order            352931 non-null  int64
#  24  battalion_id          352931 non-null  int64
#  25  jurisdiction_id       352931 non-null  int64
#  26  color                 352931 non-null  int64
#  27  code                  352931 non-null  int64
#  28  external_key          352931 non-null  int64
#  29  battalion_code        352931 non-null  object
#  30  sector_name           352931 non-null  object
#  31  input_date            352931 non-null  object
#  32  modified_date         352931 non-null  object
#  33  input_by              352931 non-null  object
#  34  modified_by           352931 non-null  object
#  35  bureau_name           352931 non-null  object
#  36  patrol_area           352931 non-null  object
#  37  command_phone_number  352931 non-null  object
#  38  primary_key           352931 non-null  int64
#  39  shape_area            352931 non-null  float64
#  40  shape_length          352931 non-null  float64
# dtypes: bool(2), datetime64[ns](5), float64(6), int64(8), object(19), timedelta64[ns](1)
# memory usage: 108.4+ MB

# %% [markdown]
# ## Univariate Exploration

# %% [markdown]
# **Let's look at distributions of some of the new columns.**

# %%
## First let me create a subset data frame with just the columns I want to look at in order to call my plot_distributions column
columns_to_explore = ['pd_district', 'district_name', 'battalion_id', 'jurisdiction_id', 'sector_name', 'bureau_name', 'patrol_area']
univariate_df = df[columns_to_explore]
univariate_df.head()
# Out:
#   pd_district district_name  battalion_id  jurisdiction_id sector_name  \
# 0    GEORGE 3      GEORGE 3           194               15      GEORGE
# 1    GEORGE 3      GEORGE 3           194               15      GEORGE
# 2    GEORGE 3      GEORGE 3           194               15      GEORGE
# 3    GEORGE 3      GEORGE 3           194               15      GEORGE
# 4    GEORGE 3      GEORGE 3           194               15      GEORGE
#
#   bureau_name patrol_area
# 0       NORTH        DTAC
# 1       NORTH        DTAC
# 2       NORTH        DTAC
# 3       NORTH        DTAC
# 4       NORTH        DTAC

# %%
plot_distributions(univariate_df)

# %% [markdown]
# **We have generally uniform distributions for these features but there are also clearly some jurisdictions, sectors, battalions, patrol ares, etc. that get higher levels of crime. The data types of some features are making them display strangely. I need to make sure I change them to the appropirate type.**

# %% [markdown]
# ### Change Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352931 entries, 0 to 352930
# Data columns (total 41 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   crime_type            352931 non-null  object
#  1   family_violence       352931 non-null  object
#  2   occurrence_time       352931 non-null  datetime64[ns]
#  3   occurrence_date       352931 non-null  datetime64[ns]
#  4   report_time           352931 non-null  datetime64[ns]
#  5   report_date           352931 non-null  datetime64[ns]
#  6   location_type         352931 non-null  object
#  7   address               352931 non-null  object
#  8   zip_code              352931 non-null  float64
#  9   council_district      352931 non-null  float64
#  10  sector                352931 non-null  object
#  11  district              352931 non-null  object
#  12  latitude              352931 non-null  float64
#  13  longitude             352931 non-null  float64
#  14  clearance_status      352931 non-null  object
#  15  clearance_date        352931 non-null  datetime64[ns]
#  16  cleared               352931 non-null  bool
#  17  time_to_report        352931 non-null  timedelta64[ns]
#  18  pandemic_lockdown     352931 non-null  bool
#  19  pd_district           352931 non-null  object
#  20  the_geom              352931 non-null  object
#  21  objectid              352931 non-null  int64
#  22  district_name         352931 non-null  object
#  23  sort_order            352931 non-null  int64
#  24  battalion_id          352931 non-null  int64
#  25  jurisdiction_id       352931 non-null  int64
#  26  color                 352931 non-null  int64
#  27  code                  352931 non-null  int64
#  28  external_key          352931 non-null  int64
#  29  battalion_code        352931 non-null  object
#  30  sector_name           352931 non-null  object
#  31  input_date            352931 non-null  object
#  32  modified_date         352931 non-null  object
#  33  input_by              352931 non-null  object
#  34  modified_by           352931 non-null  object
#  35  bureau_name           352931 non-null  object
#  36  patrol_area           352931 non-null  object
#  37  command_phone_number  352931 non-null  object
#  38  primary_key           352931 non-null  int64
#  39  shape_area            352931 non-null  float64
#  40  shape_length          352931 non-null  float64
# dtypes: bool(2), datetime64[ns](5), float64(6), int64(8), object(19), timedelta64[ns](1)
# memory usage: 116.4+ MB

# %%
df.battalion_id.value_counts()
# Out:
# 174    49760
# 164    45033
# 184    42534
# 21     41851
# 205    41761
# 144    37392
# 400    37344
# 215    35559
# 194    21697
# Name: battalion_id, dtype: int64

# %%
df.battalion_code.value_counts()
# Out:
# E1      49760
# D1      45033
# F1      42534
# A1      41851
# H1      41761
# B1      37392
# CHAR    37344
# I1      35559
# G1      21697
# Name: battalion_code, dtype: int64

# %% [markdown]
# **Battalion code and id seem to be exactly duplicated.**

# %%
df.jurisdiction_id.value_counts()
# Out:
# 13    49760
# 12    45033
# 14    42534
# 6     41851
# 59    41761
# 10    37392
# 11    37344
# 60    35559
# 15    21697
# Name: jurisdiction_id, dtype: int64

# %%
df.color.value_counts() # Really not sure what this means
# Out:
# 16711680    102417
# 16711808    100790
# 16744448     84385
# 16744576     43642
# 16776960     21697
# Name: color, dtype: int64

# %%
df.bureau_name.value_counts()
# Out:
# SOUTH      129328
# CENTRAL    122663
# NORTH      100940
# Name: bureau_name, dtype: int64

# %% [markdown]
# **Columns that need data types changed: battalion_id, jurisdiction_id, code.**

# %%
df.battalion_id = df.battalion_id.astype('object')
df.jurisdiction_id = df.jurisdiction_id.astype('object')
df.code = df.code.astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352931 entries, 0 to 352930
# Data columns (total 41 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   crime_type            352931 non-null  object
#  1   family_violence       352931 non-null  object
#  2   occurrence_time       352931 non-null  datetime64[ns]
#  3   occurrence_date       352931 non-null  datetime64[ns]
#  4   report_time           352931 non-null  datetime64[ns]
#  5   report_date           352931 non-null  datetime64[ns]
#  6   location_type         352931 non-null  object
#  7   address               352931 non-null  object
#  8   zip_code              352931 non-null  float64
#  9   council_district      352931 non-null  float64
#  10  sector                352931 non-null  object
#  11  district              352931 non-null  object
#  12  latitude              352931 non-null  float64
#  13  longitude             352931 non-null  float64
#  14  clearance_status      352931 non-null  object
#  15  clearance_date        352931 non-null  datetime64[ns]
#  16  cleared               352931 non-null  bool
#  17  time_to_report        352931 non-null  timedelta64[ns]
#  18  pandemic_lockdown     352931 non-null  bool
#  19  pd_district           352931 non-null  object
#  20  the_geom              352931 non-null  object
#  21  objectid              352931 non-null  int64
#  22  district_name         352931 non-null  object
#  23  sort_order            352931 non-null  int64
#  24  battalion_id          352931 non-null  object
#  25  jurisdiction_id       352931 non-null  object
#  26  color                 352931 non-null  int64
#  27  code                  352931 non-null  object
#  28  external_key          352931 non-null  int64
#  29  battalion_code        352931 non-null  object
#  30  sector_name           352931 non-null  object
#  31  input_date            352931 non-null  object
#  32  modified_date         352931 non-null  object
#  33  input_by              352931 non-null  object
#  34  modified_by           352931 non-null  object
#  35  bureau_name           352931 non-null  object
#  36  patrol_area           352931 non-null  object
#  37  command_phone_number  352931 non-null  object
#  38  primary_key           352931 non-null  int64
#  39  shape_area            352931 non-null  float64
#  40  shape_length          352931 non-null  float64
# dtypes: bool(2), datetime64[ns](5), float64(6), int64(5), object(22), timedelta64[ns](1)
# memory usage: 116.4+ MB

# %%
plot_distribution(df, 'battalion_code')

# %%
plot_distribution(df, 'jurisdiction_id')

# %% [markdown]
# ## Split the Data Before Multivariate Analysis

# %%
train, validate, test = split_data(df)
train.shape, validate.shape, test.shape
# Out:
# ((197640, 41), (84704, 41), (70587, 41))

# %% [markdown]
# ## Exploration

# %% [markdown]
# ### Question 1: Is clearance rate dependent on patrol area?

# %%
# create pie chart - I dont think this viz is doing what I want it to do
train.patrol_area.value_counts().plot(kind='pie', autopct="%1.1f%%")
# remove y axis label
plt.ylabel(None)
#add title
plt.title('Percentage of Crime by Patrol Area')
plt.show()

# %%
# Calculate overall clearance rate
clearance_rate = train.cleared.mean()
# Plot the relationship
plt.title("Relationship Between Patrol Area and Clearance Rate", fontsize=20)
train.groupby('patrol_area').cleared.mean().sort_values(ascending=False).plot.bar()
plt.axhline(clearance_rate, label="Overall Clearance rate")
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Patrol Area', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
None

# %% [markdown]
# **Takeaways:**
# - It look like DTAC (Downtown Area Command) has significantly higher clearance rate -- Is this simply because theres more crime there or more resources allocated there?
# - All the western patrol areas have the lowerst clearance rates while the east and central areas are generally higher.

# %% [markdown]
# **I'll run a quick chi^2 test to confirm the statistical dependency.**
#
# $H0$: Patrol area and clearance are independent of eachother.
#
# $Ha$: Patrol area and clearance are dependent on eachother.
#
# *Setting my confidence level at 95% which makes my alpha = .05*

# %%
target = train.cleared
chi2(train.patrol_area, target)
# Out:
# The chi2 value between the two variables is 2622.8906343934905 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %% [markdown]
# **Let's look at the top crimes in each patrol area...**

# %%
train.groupby('patrol_area').crime_type.value_counts().sort_values(ascending=False)
# Out:
# patrol_area   crime_type
# NORTHWEST     BURGLARY OF VEHICLE               3034
# SOUTHWEST     BURGLARY OF VEHICLE               3003
# CENTRALWEST   BURGLARY OF VEHICLE               3001
# SOUTHEAST     FAMILY DISTURBANCE                2522
# SOUTHWEST     THEFT                             2436
#                                                 ...
# SOUTHCENTRAL  FRAUD DESTRUCTION OF A WRITING       1
#               FORGERY OF IDENTIFICATION            1
#               FEDERAL VIOL/OTHER                   1
#               FALSE STATEMENT -OBTAIN CREDIT       1
# SOUTHWEST     VOCO - ALCOHOL  CONSUMPTION          1
# Name: crime_type, Length: 2037, dtype: int64

# %%
train.groupby(['patrol_area','crime_type']).max()
# Out:
#                                            family_violence  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                                 N
#             ABUSE OF CORPSE                              N
#             AGG ASLT ENHANC STRANGL/SUFFOC               Y
#             AGG ASLT STRANGLE/SUFFOCATE                  Y
#             AGG ASLT W/MOTOR VEH FAM/DAT V               Y
# ...                                                    ...
# SOUTHWEST   VIOL STATE LAW - OTHER                       N
#             VIOL STAY AWAY ORDER                         N
#             VIOL TEMP EX PARTE  ORDER                    N
#             VOCO - ALCOHOL  CONSUMPTION                  N
#             WARRANT ARREST NON TRAFFIC                   N
#
#                                                occurrence_time  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                   2020-07-28 19:13:00
#             ABUSE OF CORPSE                2020-04-30 21:50:00
#             AGG ASLT ENHANC STRANGL/SUFFOC 2021-07-03 02:00:00
#             AGG ASLT STRANGLE/SUFFOCATE    2021-12-26 12:36:00
#             AGG ASLT W/MOTOR VEH FAM/DAT V 2021-12-16 03:01:00
# ...                                                        ...
# SOUTHWEST   VIOL STATE LAW - OTHER         2021-12-21 12:45:00
#             VIOL STAY AWAY ORDER           2018-02-10 11:58:00
#             VIOL TEMP EX PARTE  ORDER      2018-05-14 12:00:00
#             VOCO - ALCOHOL  CONSUMPTION    2018-11-06 12:16:00
#             WARRANT ARREST NON TRAFFIC     2021-11-17 10:00:00
#
#                                            occurrence_date  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                        2020-07-28
#             ABUSE OF CORPSE                     2020-04-30
#             AGG ASLT ENHANC STRANGL/SUFFOC      2021-07-03
#             AGG ASLT STRANGLE/SUFFOCATE         2021-12-26
#             AGG ASLT W/MOTOR VEH FAM/DAT V      2021-12-16
# ...                                                    ...
# SOUTHWEST   VIOL STATE LAW - OTHER              2021-12-21
#             VIOL STAY AWAY ORDER                2018-02-10
#             VIOL TEMP EX PARTE  ORDER           2018-05-14
#             VOCO - ALCOHOL  CONSUMPTION         2018-11-06
#             WARRANT ARREST NON TRAFFIC          2021-11-17
#
#                                                    report_time report_date  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                   2020-07-28 19:13:00  2020-07-28
#             ABUSE OF CORPSE                2020-04-30 21:50:00  2020-04-30
#             AGG ASLT ENHANC STRANGL/SUFFOC 2021-10-01 16:00:00  2021-10-01
#             AGG ASLT STRANGLE/SUFFOCATE    2021-12-26 12:36:00  2021-12-26
#             AGG ASLT W/MOTOR VEH FAM/DAT V 2021-12-16 03:01:00  2021-12-16
# ...                                                        ...         ...
# SOUTHWEST   VIOL STATE LAW - OTHER         2021-12-21 12:45:00  2021-12-21
#             VIOL STAY AWAY ORDER           2018-02-10 11:58:00  2018-02-10
#             VIOL TEMP EX PARTE  ORDER      2018-05-14 21:22:00  2018-05-14
#             VOCO - ALCOHOL  CONSUMPTION    2018-11-06 12:16:00  2018-11-06
#             WARRANT ARREST NON TRAFFIC     2021-11-17 10:13:00  2021-11-17
#
#                                                          location_type  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                              RESIDENCE / HOME
#             ABUSE OF CORPSE                           RESIDENCE / HOME
#             AGG ASLT ENHANC STRANGL/SUFFOC            RESIDENCE / HOME
#             AGG ASLT STRANGLE/SUFFOCATE     SHELTER-MISSION / HOMELESS
#             AGG ASLT W/MOTOR VEH FAM/DAT V   PARKING /DROP LOT/ GARAGE
# ...                                                                ...
# SOUTHWEST   VIOL STATE LAW - OTHER           PARKING /DROP LOT/ GARAGE
#             VIOL STAY AWAY ORDER             PARKING /DROP LOT/ GARAGE
#             VIOL TEMP EX PARTE  ORDER             SERVICE/ GAS STATION
#             VOCO - ALCOHOL  CONSUMPTION                OTHER / UNKNOWN
#             WARRANT ARREST NON TRAFFIC                SPECIALTY  STORE
#
#                                                                        address  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                                     8307 GARCREEK CIR
#             ABUSE OF CORPSE                                      1143 SHADY LN
#             AGG ASLT ENHANC STRANGL/SUFFOC                         800 NILE ST
#             AGG ASLT STRANGLE/SUFFOCATE       TANNEHILL LN / SAMUEL HUSTON AVE
#             AGG ASLT W/MOTOR VEH FAM/DAT V  WEBBERVILLE RD / SAMUEL HUSTON AVE
# ...                                                                        ...
# SOUTHWEST   VIOL STATE LAW - OTHER                    S LAMAR BLVD / KINNEY RD
#             VIOL STAY AWAY ORDER                2901 S CAPITAL OF TEXAS HWY NB
#             VIOL TEMP EX PARTE  ORDER            1913 W BEN WHITE BLVD SVRD EB
#             VOCO - ALCOHOL  CONSUMPTION                       4330 MANCHACA RD
#             WARRANT ARREST NON TRAFFIC            W OLTORF ST / S CONGRESS AVE
#
#                                             zip_code  council_district  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                     78724.0               1.0
#             ABUSE OF CORPSE                  78721.0               3.0
#             AGG ASLT ENHANC STRANGL/SUFFOC   78725.0               9.0
#             AGG ASLT STRANGLE/SUFFOCATE      78754.0               9.0
#             AGG ASLT W/MOTOR VEH FAM/DAT V   78724.0               3.0
# ...                                              ...               ...
# SOUTHWEST   VIOL STATE LAW - OTHER           78749.0               8.0
#             VIOL STAY AWAY ORDER             78746.0               8.0
#             VIOL TEMP EX PARTE  ORDER        78745.0               5.0
#             VOCO - ALCOHOL  CONSUMPTION      78745.0               5.0
#             WARRANT ARREST NON TRAFFIC       78749.0               9.0
#
#                                              sector district   latitude  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                    CHARLIE        7  30.310259
#             ABUSE OF CORPSE                 CHARLIE        5  30.262933
#             AGG ASLT ENHANC STRANGL/SUFFOC  CHARLIE        7  30.319028
#             AGG ASLT STRANGLE/SUFFOCATE     CHARLIE        8  30.379241
#             AGG ASLT W/MOTOR VEH FAM/DAT V  CHARLIE        8  30.378514
# ...                                             ...      ...        ...
# SOUTHWEST   VIOL STATE LAW - OTHER            DAVID        8  30.247645
#             VIOL STAY AWAY ORDER              DAVID        5  30.257886
#             VIOL TEMP EX PARTE  ORDER         DAVID        3  30.229235
#             VOCO - ALCOHOL  CONSUMPTION       DAVID        4  30.230318
#             WARRANT ARREST NON TRAFFIC        DAVID        7  30.264510
#
#                                             longitude   clearance_status  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                   -97.629472        not cleared
#             ABUSE OF CORPSE                -97.690562        not cleared
#             AGG ASLT ENHANC STRANGL/SUFFOC -97.629824        not cleared
#             AGG ASLT STRANGLE/SUFFOCATE    -97.601395        not cleared
#             AGG ASLT W/MOTOR VEH FAM/DAT V -97.601398        not cleared
# ...                                               ...                ...
# SOUTHWEST   VIOL STATE LAW - OTHER         -97.759241        not cleared
#             VIOL STAY AWAY ORDER           -97.807007        not cleared
#             VIOL TEMP EX PARTE  ORDER      -97.786778        not cleared
#             VOCO - ALCOHOL  CONSUMPTION    -97.788177  cleared by arrest
#             WARRANT ARREST NON TRAFFIC     -97.745739        not cleared
#
#                                            clearance_date  cleared  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                       2020-08-27     True
#             ABUSE OF CORPSE                    2020-05-01    False
#             AGG ASLT ENHANC STRANGL/SUFFOC     2021-10-11     True
#             AGG ASLT STRANGLE/SUFFOCATE        2022-01-07     True
#             AGG ASLT W/MOTOR VEH FAM/DAT V     2021-12-23     True
# ...                                                   ...      ...
# SOUTHWEST   VIOL STATE LAW - OTHER             2021-12-30     True
#             VIOL STAY AWAY ORDER               2018-02-23    False
#             VIOL TEMP EX PARTE  ORDER          2018-05-22     True
#             VOCO - ALCOHOL  CONSUMPTION        2019-01-11     True
#             WARRANT ARREST NON TRAFFIC         2021-11-17     True
#
#                                               time_to_report  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                     0 days 00:00:00
#             ABUSE OF CORPSE                  0 days 00:00:00
#             AGG ASLT ENHANC STRANGL/SUFFOC 116 days 16:00:00
#             AGG ASLT STRANGLE/SUFFOCATE    255 days 00:00:00
#             AGG ASLT W/MOTOR VEH FAM/DAT V  18 days 06:49:00
# ...                                                      ...
# SOUTHWEST   VIOL STATE LAW - OTHER           7 days 00:00:00
#             VIOL STAY AWAY ORDER             0 days 00:00:00
#             VIOL TEMP EX PARTE  ORDER        0 days 09:22:00
#             VOCO - ALCOHOL  CONSUMPTION      0 days 00:00:00
#             WARRANT ARREST NON TRAFFIC       1 days 12:41:00
#
#                                             pandemic_lockdown pd_district  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                                 True   CHARLIE 7
#             ABUSE OF CORPSE                              True   CHARLIE 5
#             AGG ASLT ENHANC STRANGL/SUFFOC              False   CHARLIE 7
#             AGG ASLT STRANGLE/SUFFOCATE                  True   CHARLIE 8
#             AGG ASLT W/MOTOR VEH FAM/DAT V              False   CHARLIE 8
# ...                                                       ...         ...
# SOUTHWEST   VIOL STATE LAW - OTHER                       True     DAVID 8
#             VIOL STAY AWAY ORDER                        False     DAVID 5
#             VIOL TEMP EX PARTE  ORDER                   False     DAVID 3
#             VOCO - ALCOHOL  CONSUMPTION                 False     DAVID 4
#             WARRANT ARREST NON TRAFFIC                  False     DAVID 7
#
#                                                                                      the_geom  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                    MULTIPOLYGON (((-97.62281561087 30.33085427663...
#             ABUSE OF CORPSE                 MULTIPOLYGON (((-97.688776778113 30.2761751284...
#             AGG ASLT ENHANC STRANGL/SUFFOC  MULTIPOLYGON (((-97.715215240505 30.3018892311...
#             AGG ASLT STRANGLE/SUFFOCATE     MULTIPOLYGON (((-97.715215240505 30.3018892311...
#             AGG ASLT W/MOTOR VEH FAM/DAT V  MULTIPOLYGON (((-97.697914171742 30.2735607234...
# ...                                                                                       ...
# SOUTHWEST   VIOL STATE LAW - OTHER          MULTIPOLYGON (((-97.893226860156 30.2139042024...
#             VIOL STAY AWAY ORDER            MULTIPOLYGON (((-97.780302118398 30.2678522249...
#             VIOL TEMP EX PARTE  ORDER       MULTIPOLYGON (((-97.75145149435 30.21644972810...
#             VOCO - ALCOHOL  CONSUMPTION     MULTIPOLYGON (((-97.783022731369 30.2445288343...
#             WARRANT ARREST NON TRAFFIC      MULTIPOLYGON (((-97.881385230617 30.2626769868...
#
#                                             objectid district_name  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                          30     CHARLIE 7
#             ABUSE OF CORPSE                       17     CHARLIE 5
#             AGG ASLT ENHANC STRANGL/SUFFOC        90     CHARLIE 7
#             AGG ASLT STRANGLE/SUFFOCATE           90     CHARLIE 8
#             AGG ASLT W/MOTOR VEH FAM/DAT V        90     CHARLIE 8
# ...                                              ...           ...
# SOUTHWEST   VIOL STATE LAW - OTHER                84       DAVID 8
#             VIOL STAY AWAY ORDER                   2       DAVID 5
#             VIOL TEMP EX PARTE  ORDER              5       DAVID 3
#             VOCO - ALCOHOL  CONSUMPTION           81       DAVID 4
#             WARRANT ARREST NON TRAFFIC            84       DAVID 7
#
#                                             sort_order  battalion_id  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                             1           400
#             ABUSE OF CORPSE                          1           400
#             AGG ASLT ENHANC STRANGL/SUFFOC           1           400
#             AGG ASLT STRANGLE/SUFFOCATE              1           400
#             AGG ASLT W/MOTOR VEH FAM/DAT V           1           400
# ...                                                ...           ...
# SOUTHWEST   VIOL STATE LAW - OTHER                   1           164
#             VIOL STAY AWAY ORDER                     1           164
#             VIOL TEMP EX PARTE  ORDER                1           164
#             VOCO - ALCOHOL  CONSUMPTION              1           164
#             WARRANT ARREST NON TRAFFIC               1           164
#
#                                             jurisdiction_id     color  code  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                                 11  16744576  1282
#             ABUSE OF CORPSE                              11  16744576  1281
#             AGG ASLT ENHANC STRANGL/SUFFOC               11  16744576  1282
#             AGG ASLT STRANGLE/SUFFOCATE                  11  16744576  1282
#             AGG ASLT W/MOTOR VEH FAM/DAT V               11  16744576  1282
# ...                                                     ...       ...   ...
# SOUTHWEST   VIOL STATE LAW - OTHER                       12  16711808  1286
#             VIOL STAY AWAY ORDER                         12  16711680  1285
#             VIOL TEMP EX PARTE  ORDER                    12  16711808  1283
#             VOCO - ALCOHOL  CONSUMPTION                  12  16711680  1286
#             WARRANT ARREST NON TRAFFIC                   12  16711808  1286
#
#                                             external_key battalion_code  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                            1282           CHAR
#             ABUSE OF CORPSE                         1281           CHAR
#             AGG ASLT ENHANC STRANGL/SUFFOC          1282           CHAR
#             AGG ASLT STRANGLE/SUFFOCATE             1282           CHAR
#             AGG ASLT W/MOTOR VEH FAM/DAT V          1282           CHAR
# ...                                                  ...            ...
# SOUTHWEST   VIOL STATE LAW - OTHER                  1286             D1
#             VIOL STAY AWAY ORDER                    1285             D1
#             VIOL TEMP EX PARTE  ORDER               1283             D1
#             VOCO - ALCOHOL  CONSUMPTION             1286             D1
#             WARRANT ARREST NON TRAFFIC              1286             D1
#
#                                            sector_name  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                       CHARLIE
#             ABUSE OF CORPSE                    CHARLIE
#             AGG ASLT ENHANC STRANGL/SUFFOC     CHARLIE
#             AGG ASLT STRANGLE/SUFFOCATE        CHARLIE
#             AGG ASLT W/MOTOR VEH FAM/DAT V     CHARLIE
# ...                                                ...
# SOUTHWEST   VIOL STATE LAW - OTHER               DAVID
#             VIOL STAY AWAY ORDER                 DAVID
#             VIOL TEMP EX PARTE  ORDER            DAVID
#             VOCO - ALCOHOL  CONSUMPTION          DAVID
#             WARRANT ARREST NON TRAFFIC           DAVID
#
#                                                               input_date  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                    12/22/2014 11:31:16 AM +0000
#             ABUSE OF CORPSE                 12/22/2014 11:31:16 AM +0000
#             AGG ASLT ENHANC STRANGL/SUFFOC  12/22/2014 11:31:16 AM +0000
#             AGG ASLT STRANGLE/SUFFOCATE     12/22/2014 11:31:16 AM +0000
#             AGG ASLT W/MOTOR VEH FAM/DAT V  12/22/2014 11:31:16 AM +0000
# ...                                                                  ...
# SOUTHWEST   VIOL STATE LAW - OTHER          12/22/2014 11:31:16 AM +0000
#             VIOL STAY AWAY ORDER            12/22/2014 11:31:16 AM +0000
#             VIOL TEMP EX PARTE  ORDER       12/22/2014 11:31:16 AM +0000
#             VOCO - ALCOHOL  CONSUMPTION     12/22/2014 11:31:16 AM +0000
#             WARRANT ARREST NON TRAFFIC      12/22/2014 11:31:16 AM +0000
#
#                                                            modified_date  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                    10/09/2018 01:42:18 PM +0000
#             ABUSE OF CORPSE                 10/09/2018 01:41:43 PM +0000
#             AGG ASLT ENHANC STRANGL/SUFFOC  10/09/2018 01:42:18 PM +0000
#             AGG ASLT STRANGLE/SUFFOCATE     10/09/2018 01:42:18 PM +0000
#             AGG ASLT W/MOTOR VEH FAM/DAT V  10/09/2018 01:42:18 PM +0000
# ...                                                                  ...
# SOUTHWEST   VIOL STATE LAW - OTHER          10/09/2018 01:44:29 PM +0000
#             VIOL STAY AWAY ORDER            09/06/2018 08:39:41 AM +0000
#             VIOL TEMP EX PARTE  ORDER       09/06/2018 08:39:25 AM +0000
#             VOCO - ALCOHOL  CONSUMPTION     10/09/2018 01:44:27 PM +0000
#             WARRANT ARREST NON TRAFFIC      10/09/2018 01:44:29 PM +0000
#
#                                                  input_by modified_by  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                    bmartinlimuel   APD_ADMIN
#             ABUSE OF CORPSE                 bmartinlimuel   APD_ADMIN
#             AGG ASLT ENHANC STRANGL/SUFFOC  bmartinlimuel   APD_ADMIN
#             AGG ASLT STRANGLE/SUFFOCATE     bmartinlimuel   APD_ADMIN
#             AGG ASLT W/MOTOR VEH FAM/DAT V  bmartinlimuel   APD_ADMIN
# ...                                                   ...         ...
# SOUTHWEST   VIOL STATE LAW - OTHER          bmartinlimuel   APD_ADMIN
#             VIOL STAY AWAY ORDER            bmartinlimuel      AP7657
#             VIOL TEMP EX PARTE  ORDER       bmartinlimuel      AP7657
#             VOCO - ALCOHOL  CONSUMPTION     bmartinlimuel   APD_ADMIN
#             WARRANT ARREST NON TRAFFIC      bmartinlimuel   APD_ADMIN
#
#                                            bureau_name command_phone_number  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                       CENTRAL         512-974-5900
#             ABUSE OF CORPSE                    CENTRAL         512-974-5900
#             AGG ASLT ENHANC STRANGL/SUFFOC     CENTRAL         512-974-5900
#             AGG ASLT STRANGLE/SUFFOCATE        CENTRAL         512-974-5900
#             AGG ASLT W/MOTOR VEH FAM/DAT V     CENTRAL         512-974-5900
# ...                                                ...                  ...
# SOUTHWEST   VIOL STATE LAW - OTHER               SOUTH         512-974-8100
#             VIOL STAY AWAY ORDER                 SOUTH         512-974-8100
#             VIOL TEMP EX PARTE  ORDER            SOUTH         512-974-8100
#             VOCO - ALCOHOL  CONSUMPTION          SOUTH         512-974-8100
#             WARRANT ARREST NON TRAFFIC           SOUTH         512-974-8100
#
#                                             primary_key    shape_area  \
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                             64  2.790678e+08
#             ABUSE OF CORPSE                          56  1.083276e+08
#             AGG ASLT ENHANC STRANGL/SUFFOC           64  2.790678e+08
#             AGG ASLT STRANGLE/SUFFOCATE              64  2.790678e+08
#             AGG ASLT W/MOTOR VEH FAM/DAT V           64  2.790678e+08
# ...                                                 ...           ...
# SOUTHWEST   VIOL STATE LAW - OTHER                   88  2.740162e+08
#             VIOL STAY AWAY ORDER                     14  2.268465e+08
#             VIOL TEMP EX PARTE  ORDER                32  8.988958e+07
#             VOCO - ALCOHOL  CONSUMPTION              87  1.491496e+08
#             WARRANT ARREST NON TRAFFIC               88  2.691142e+08
#
#                                              shape_length
# patrol_area crime_type
# CENTRALEAST ABUSE OF 911                    173675.204573
#             ABUSE OF CORPSE                  45315.720218
#             AGG ASLT ENHANC STRANGL/SUFFOC  173675.204573
#             AGG ASLT STRANGLE/SUFFOCATE     173675.204573
#             AGG ASLT W/MOTOR VEH FAM/DAT V  173675.204573
# ...                                                   ...
# SOUTHWEST   VIOL STATE LAW - OTHER          136909.636633
#             VIOL STAY AWAY ORDER            115450.915093
#             VIOL TEMP EX PARTE  ORDER        39192.878012
#             VOCO - ALCOHOL  CONSUMPTION     104111.511168
#             WARRANT ARREST NON TRAFFIC      115450.915093
#
# [2037 rows x 39 columns]

# %% [markdown]
# **Can't quite figure this out. I'll ask for assistance later.**

# %%
# Top 10 crimes by frequency
train.crime_type.value_counts().head(10)
# Out:
# BURGLARY OF VEHICLE               19665
# THEFT                             16662
# FAMILY DISTURBANCE                14055
# CRIMINAL MISCHIEF                 11103
# AUTO THEFT                         7279
# ASSAULT W/INJURY-FAM/DATE VIOL     7160
# HARASSMENT                         5860
# THEFT BY SHOPLIFTING               5731
# ASSAULT WITH INJURY                5592
# DWI                                4435
# Name: crime_type, dtype: int64

# %% [markdown]
# ### Question 2: Is clearance rate dependent on sector?
#
# **I'll run a quick chi^2 test to check the statistical dependency.**
#
# $H0$: Police sector and clearance are independent of eachother.
#
# $Ha$: Police sector and clearance are dependent on eachother.
#
# *Setting my confidence level at 95% which makes my alpha = .05*

# %%
chi2(train.sector_name, target)
# Out:
# The chi2 value between the two variables is 2622.8906343934896 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %%
# Plot the relationship
plt.title("Relationship Between Sector and Clearance Rate", fontsize=20)
train.groupby('sector_name').cleared.mean().sort_values(ascending=False).plot.bar()
plt.axhline(clearance_rate, label="Overall Clearance rate")
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Sector', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
None

# %%
plt.title("Relationship Between Patrol Area and Clearance Rate", fontsize=20)
sns.barplot(x="patrol_area", y="cleared", data=train, color ='royalblue', ci=None, 
            order= ['DTAC', 'NORTHCENTRAL', 'CENTRALEAST', 'SOUTHCENTRAL', 'NORTHEAST',
                    'SOUTHEAST', 'SOUTHWEST', 'CENTRALWEST', 'NORTHWEST'])
plt.axhline(clearance_rate, label="Overall Clearance rate", linestyle = '--', alpha=.8, color='orange')
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Crime Type', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
plt.show()

# %%
plt.title("Relationship Between Patrol Area and Clearance Rate", fontsize=20)
sns.barplot(x="patrol_area", y="cleared", data=train, color ='royalblue', ci=None, 
            order= )
plt.axhline(clearance_rate, label="Overall Clearance rate", linestyle = '--', alpha=.8, color='orange')
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Crime Type', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
plt.show()

# %%
ax = sns.countplot(data = train, y = 'patrol_area',order = train['patrol_area'].value_counts(ascending = False).index, color = 'seagreen')
plt.xlabel('Crime Count',fontsize=14)# set up the x axis. 
plt.ylabel('Patrol Area',fontsize=14)# set up the y axis
plt.title('Crime Rate by Patrol Area',fontsize=20) # set up the title.
plt.show()

# %% [markdown]
# **The relationship here look almost exactly the same as with patrol area. They might represent the excact same area. Let's look at the exact numbers.**

# %%
train.groupby('sector_name').cleared.mean().sort_values(ascending=False)
# Out:
# sector_name
# GEORGE     0.353287
# IDA        0.239759
# CHARLIE    0.234353
# HENRY      0.217916
# EDWARD     0.203385
# FRANK      0.189283
# DAVID      0.183796
# BAKER      0.164513
# ADAM       0.152729
# Name: cleared, dtype: float64

# %%
train.groupby('patrol_area').cleared.mean().sort_values(ascending=False)
# Out:
# patrol_area
# DTAC            0.353287
# NORTHCENTRAL    0.239759
# CENTRALEAST     0.234353
# SOUTHCENTRAL    0.217916
# NORTHEAST       0.203385
# SOUTHEAST       0.189283
# SOUTHWEST       0.183796
# CENTRALWEST     0.164513
# NORTHWEST       0.152729
# Name: cleared, dtype: float64

# %% [markdown]
# **It looks like they do correlate exactly.**

# %% [markdown]
# ### Question 3: Is clearance rate dependent on battalion_code?
#
# **I'll run a quick chi^2 test to check the statistical dependency.**
#
# $H0$: Battalion code and clearance are independent of eachother.
#
# $Ha$: Battalion code and clearance are dependent on eachother.
#
# *Setting my confidence level at 95% which makes my alpha = .05*

# %%
chi2(train.battalion_code, target)
# Out:
# The chi2 value between the two variables is 2622.8906343934896 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %%
# Plot the relationship
plt.title("Relationship Between Sector and Clearance Rate", fontsize=20)
train.groupby('battalion_code').cleared.mean().sort_values(ascending=False).plot.bar()
plt.axhline(clearance_rate, label="Overall Clearance rate")
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Battalion', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
None

# %% [markdown]
# **These also seem like they might mirror patrol area and sector.**

# %%
train.groupby('sector_name').cleared.mean().sort_values(ascending=False)
# Out:
# sector_name
# GEORGE     0.353287
# IDA        0.239759
# CHARLIE    0.234353
# HENRY      0.217916
# EDWARD     0.203385
# FRANK      0.189283
# DAVID      0.183796
# BAKER      0.164513
# ADAM       0.152729
# Name: cleared, dtype: float64

# %%
train.groupby('patrol_area').cleared.mean().sort_values(ascending=False)
# Out:
# patrol_area
# DTAC            0.353287
# NORTHCENTRAL    0.239759
# CENTRALEAST     0.234353
# SOUTHCENTRAL    0.217916
# NORTHEAST       0.203385
# SOUTHEAST       0.189283
# SOUTHWEST       0.183796
# CENTRALWEST     0.164513
# NORTHWEST       0.152729
# Name: cleared, dtype: float64

# %%
train.groupby('battalion_code').cleared.mean().sort_values(ascending=False)
# Out:
# battalion_code
# G1      0.353287
# I1      0.239759
# CHAR    0.234353
# H1      0.217916
# E1      0.203385
# F1      0.189283
# D1      0.183796
# B1      0.164513
# A1      0.152729
# Name: cleared, dtype: float64

# %% [markdown]
# **All three of these look like the exact same thing.**

# %% [markdown]
# ## Let's make a better pie chart to visualize our top crimes -- this time with a new column instead of a subset

# %%
train.head()
# Out:
#                          crime_type family_violence     occurrence_time  \
# 17761             CRIMINAL MISCHIEF               N 2018-03-02 09:59:00
# 36606         BURGLARY OF RESIDENCE               N 2018-02-27 09:01:00
# 234165                        THEFT               N 2018-11-21 17:32:00
# 344256  AGG ASLT STRANGLE/SUFFOCATE               Y 2021-05-31 14:05:00
# 231848          BURGLARY OF VEHICLE               N 2021-01-10 20:00:00
#
#        occurrence_date         report_time report_date          location_type  \
# 17761       2018-03-02 2018-03-02 09:59:00  2018-03-02        BAR / NIGHTCLUB
# 36606       2018-02-27 2018-02-27 13:35:00  2018-02-27       RESIDENCE / HOME
# 234165      2018-11-21 2018-11-21 18:44:00  2018-11-21  GROCERY / SUPERMARKET
# 344256      2021-05-31 2021-05-31 14:05:00  2021-05-31       RESIDENCE / HOME
# 231848      2021-01-10 2021-01-20 12:05:00  2021-01-20        OTHER / UNKNOWN
#
#                      address  zip_code  council_district   sector district  \
# 17761           708 E 6TH ST   78701.0               9.0   GEORGE        2
# 36606     401 E FAWNRIDGE DR   78753.0               4.0   EDWARD        1
# 234165        1801 E 51ST ST   78723.0               9.0    BAKER        4
# 344256  7702 HIDDEN VIEW CIR   78724.0               1.0  CHARLIE        6
# 231848     4646 MUELLER BLVD   78723.0               9.0    BAKER        4
#
#          latitude  longitude   clearance_status clearance_date  cleared  \
# 17761   30.266186 -97.735585        not cleared     2018-03-05    False
# 36606   30.357316 -97.693291  cleared by arrest     2018-02-27     True
# 234165  30.301783 -97.698668  cleared by arrest     2018-11-21     True
# 344256  30.285309 -97.641132  cleared by arrest     2021-05-31     True
# 231848  30.299869 -97.707081        not cleared     2021-02-17    False
#
#         time_to_report  pandemic_lockdown pd_district  \
# 17761  0 days 00:00:00              False    GEORGE 2
# 36606  0 days 04:34:00              False    EDWARD 1
# 234165 0 days 01:12:00              False     BAKER 4
# 344256 0 days 00:00:00              False   CHARLIE 6
# 231848 9 days 16:05:00              False     BAKER 4
#
#                                                  the_geom  objectid  \
# 17761   MULTIPOLYGON (((-97.735785029775 30.2641758809...        40
# 36606   MULTIPOLYGON (((-97.694118479216 30.3826672092...        57
# 234165  MULTIPOLYGON (((-97.710353282695 30.3095285928...        34
# 344256  MULTIPOLYGON (((-97.628753120132 30.2897194961...        50
# 231848  MULTIPOLYGON (((-97.710353282695 30.3095285928...        34
#
#        district_name  sort_order battalion_id jurisdiction_id     color  code  \
# 17761       GEORGE 2           1          194              15  16776960  1297
# 36606       EDWARD 1           1          174              13  16711680  1288
# 234165       BAKER 4           1          144              10  16711808  1277
# 344256     CHARLIE 6           1          400              11  16744576  1281
# 231848       BAKER 4           1          144              10  16711808  1277
#
#         external_key battalion_code sector_name                    input_date  \
# 17761           1297             G1      GEORGE  12/22/2014 11:31:16 AM +0000
# 36606           1288             E1      EDWARD  12/22/2014 11:31:16 AM +0000
# 234165          1277             B1       BAKER  12/22/2014 11:31:16 AM +0000
# 344256          1281           CHAR     CHARLIE  12/22/2014 11:31:16 AM +0000
# 231848          1277             B1       BAKER  12/22/2014 11:31:16 AM +0000
#
#                        modified_date       input_by modified_by bureau_name  \
# 17761   03/03/2017 08:32:53 AM +0000  bmartinlimuel      ap7657       NORTH
# 36606   10/09/2018 01:43:05 PM +0000  bmartinlimuel   APD_ADMIN     CENTRAL
# 234165  10/09/2018 01:43:09 PM +0000  bmartinlimuel   APD_ADMIN       NORTH
# 344256  09/06/2018 08:35:16 AM +0000  bmartinlimuel      AP7657     CENTRAL
# 231848  10/09/2018 01:43:09 PM +0000  bmartinlimuel   APD_ADMIN       NORTH
#
#         patrol_area command_phone_number  primary_key    shape_area  \
# 17761          DTAC         512-974-5203           19  3.600168e+06
# 36606     NORTHEAST         512-974-5500           72  8.356489e+07
# 234165  CENTRALWEST         512-974-5774           73  3.888118e+07
# 344256  CENTRALEAST         512-974-5900            3  6.854670e+07
# 231848  CENTRALWEST         512-974-5774           73  3.888118e+07
#
#         shape_length
# 17761    7922.102059
# 36606   46296.345268
# 234165  27428.465290
# 344256  52268.357217
# 231848  27428.465290

# %%
# top 10 crimes
train.crime_type.value_counts().head(10)
# Out:
# BURGLARY OF VEHICLE               19665
# THEFT                             16662
# FAMILY DISTURBANCE                14055
# CRIMINAL MISCHIEF                 11103
# AUTO THEFT                         7279
# ASSAULT W/INJURY-FAM/DATE VIOL     7160
# HARASSMENT                         5860
# THEFT BY SHOPLIFTING               5731
# ASSAULT WITH INJURY                5592
# DWI                                4435
# Name: crime_type, dtype: int64

# %% [markdown]
# **I'll have to make a new column that is a copy but label every other crime not in top 10 as 'other'.**

# %%
train['top_10_crimes'] = train.crime_type
train.top_10_crimes.value_counts().head(11)
# Out:
# BURGLARY OF VEHICLE               19665
# THEFT                             16662
# FAMILY DISTURBANCE                14055
# CRIMINAL MISCHIEF                 11103
# AUTO THEFT                         7279
# ASSAULT W/INJURY-FAM/DATE VIOL     7160
# HARASSMENT                         5860
# THEFT BY SHOPLIFTING               5731
# ASSAULT WITH INJURY                5592
# DWI                                4435
# BURGLARY OF RESIDENCE              4296
# Name: top_10_crimes, dtype: int64

# %%
#top_10_list = ['DWI', 'ASSAULT WITH INJURY', 'THEFT BY SHOPLIFTING', 'HARASSMENT', 
                 #'AUTO THEFT', 'ASSAULT W/INJURY-FAM/DATE VIOL', 'CRIMINAL MISCHIEF', 
                 #'FAMILY DISTURBANCE', 'THEFT', 'BURGLARY OF VEHICLE']

#train = train[train.crime_type.isin(top_10_list)]

# %%
  # 'clearance_status',
   # 'clearance_date',
   # 'zip_code',
    #'sector',
    #'district',
    #'latitude',
    #'longitude']
    
    #for column in null_columns:
        #df = df[~df[column].isna()]

    #return df

# %% [markdown]
# ## Pandemic Lockdown

# %%
# Importing alejandors visualizations

plt.title("Clearance rate went down during the pandemic lockdown", fontsize=20)
ax = train.groupby('pandemic_lockdown').cleared.mean().plot.bar(color=['royalblue', 'orange'])

plt.xticks(rotation = 0)
plt.yticks([.05, .10, .15, .20])
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Stay at Home Order', fontsize=13)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(1, decimals = 0));

# %% [markdown]
# ## Fix target variable viz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 352931 entries, 0 to 352930
# Data columns (total 41 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   crime_type            352931 non-null  object
#  1   family_violence       352931 non-null  object
#  2   occurrence_time       352931 non-null  datetime64[ns]
#  3   occurrence_date       352931 non-null  datetime64[ns]
#  4   report_time           352931 non-null  datetime64[ns]
#  5   report_date           352931 non-null  datetime64[ns]
#  6   location_type         352931 non-null  object
#  7   address               352931 non-null  object
#  8   zip_code              352931 non-null  float64
#  9   council_district      352931 non-null  float64
#  10  sector                352931 non-null  object
#  11  district              352931 non-null  object
#  12  latitude              352931 non-null  float64
#  13  longitude             352931 non-null  float64
#  14  clearance_status      352931 non-null  object
#  15  clearance_date        352931 non-null  datetime64[ns]
#  16  cleared               352931 non-null  bool
#  17  time_to_report        352931 non-null  timedelta64[ns]
#  18  pandemic_lockdown     352931 non-null  bool
#  19  pd_district           352931 non-null  object
#  20  the_geom              352931 non-null  object
#  21  objectid              352931 non-null  int64
#  22  district_name         352931 non-null  object
#  23  sort_order            352931 non-null  int64
#  24  battalion_id          352931 non-null  object
#  25  jurisdiction_id       352931 non-null  object
#  26  color                 352931 non-null  int64
#  27  code                  352931 non-null  object
#  28  external_key          352931 non-null  int64
#  29  battalion_code        352931 non-null  object
#  30  sector_name           352931 non-null  object
#  31  input_date            352931 non-null  object
#  32  modified_date         352931 non-null  object
#  33  input_by              352931 non-null  object
#  34  modified_by           352931 non-null  object
#  35  bureau_name           352931 non-null  object
#  36  patrol_area           352931 non-null  object
#  37  command_phone_number  352931 non-null  object
#  38  primary_key           352931 non-null  int64
#  39  shape_area            352931 non-null  float64
#  40  shape_length          352931 non-null  float64
# dtypes: bool(2), datetime64[ns](5), float64(6), int64(5), object(22), timedelta64[ns](1)
# memory usage: 116.4+ MB

# %%
plt.title("Distribution of Clearance")
    sns.countplot(y="cleared", data=df)
    plt.ylabel('Cleared')
    plt.xlabel('Clearance Count')
    plt.show()
