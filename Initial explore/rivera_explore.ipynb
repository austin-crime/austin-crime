# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns

import acquire as aq
import prepare as prep
import explore as ex


from sklearn.model_selection import train_test_split

#Settting matplotlib/seaborn defaults
plt.rc('figure', figsize=(16, 8))
plt.rcParams['axes.facecolor'] = 'whitesmoke'
plt.rcParams['axes.axisbelow'] = True
plt.rc('font', size=16)

# %%
df = aq.get_crime_data(use_cache=True)
# Out:
# Using cached csv

# %%
df.head()
# Out:
#    incident_report_number             crime_type  ucr_code family_violence  \
# 0             20221481617     FAMILY DISTURBANCE      3400               N
# 1             20221481526  BURGLARY OF RESIDENCE       500               Y
# 2             20221481586                    DWI      2100               N
# 3             20221481541            AGG ASSAULT       402               N
# 4             20221481449     FAMILY DISTURBANCE      3400               N
#
#              occ_date_time                 occ_date  occ_time  \
# 0  2022-05-28T23:34:00.000  2022-05-28T00:00:00.000      2334
# 1  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312
# 2  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312
# 3  2022-05-28T22:37:00.000  2022-05-28T00:00:00.000      2237
# 4  2022-05-28T22:34:00.000  2022-05-28T00:00:00.000      2234
#
#              rep_date_time                 rep_date  rep_time  ...  longitude  \
# 0  2022-05-28T23:34:00.000  2022-05-28T00:00:00.000      2334  ... -97.693064
# 1  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312  ... -97.735209
# 2  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312  ... -97.713580
# 3  2022-05-28T22:37:00.000  2022-05-28T00:00:00.000      2237  ... -97.703725
# 4  2022-05-28T22:34:00.000  2022-05-28T00:00:00.000      2234  ... -97.747848
#
#                                             location  \
# 0  {'latitude': '30.24071184', 'longitude': '-97....
# 1  {'latitude': '30.1996283', 'longitude': '-97.7...
# 2  {'latitude': '30.24610845', 'longitude': '-97....
# 3  {'latitude': '30.36871033', 'longitude': '-97....
# 4  {'latitude': '30.19838244', 'longitude': '-97....
#
#    :@computed_region_a3it_2a2z  :@computed_region_8spj_utxs  \
# 0                       3256.0                          3.0
# 1                       3258.0                          2.0
# 2                       3256.0                          3.0
# 3                       3646.0                          4.0
# 4                       3258.0                          2.0
#
#   :@computed_region_q9nd_rr82 ucr_category  category_description  \
# 0                         3.0          NaN                   NaN
# 1                         4.0          220              Burglary
# 2                         3.0          NaN                   NaN
# 3                         9.0          13A    Aggravated Assault
# 4                         4.0          NaN                   NaN
#
#    :@computed_region_qwte_z96m  clearance_status  clearance_date
# 0                          NaN               NaN             NaN
# 1                       2268.0               NaN             NaN
# 2                       1599.0               NaN             NaN
# 3                       3851.0               NaN             NaN
# 4                          NaN               NaN             NaN
#
# [5 rows x 31 columns]

# %%
df2 = pd.read_csv('Crime_Reports.csv')
df2.head()
# Out:
#    incident_report_number             crime_type  ucr_code family_violence  \
# 0             20221481617     FAMILY DISTURBANCE      3400               N
# 1             20221481526  BURGLARY OF RESIDENCE       500               Y
# 2             20221481586                    DWI      2100               N
# 3             20221481541            AGG ASSAULT       402               N
# 4             20221481449     FAMILY DISTURBANCE      3400               N
#
#              occ_date_time                 occ_date  occ_time  \
# 0  2022-05-28T23:34:00.000  2022-05-28T00:00:00.000      2334
# 1  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312
# 2  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312
# 3  2022-05-28T22:37:00.000  2022-05-28T00:00:00.000      2237
# 4  2022-05-28T22:34:00.000  2022-05-28T00:00:00.000      2234
#
#              rep_date_time                 rep_date  rep_time  ...  longitude  \
# 0  2022-05-28T23:34:00.000  2022-05-28T00:00:00.000      2334  ... -97.693064
# 1  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312  ... -97.735209
# 2  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312  ... -97.713580
# 3  2022-05-28T22:37:00.000  2022-05-28T00:00:00.000      2237  ... -97.703725
# 4  2022-05-28T22:34:00.000  2022-05-28T00:00:00.000      2234  ... -97.747848
#
#                                             location  \
# 0  {'latitude': '30.24071184', 'longitude': '-97....
# 1  {'latitude': '30.1996283', 'longitude': '-97.7...
# 2  {'latitude': '30.24610845', 'longitude': '-97....
# 3  {'latitude': '30.36871033', 'longitude': '-97....
# 4  {'latitude': '30.19838244', 'longitude': '-97....
#
#    :@computed_region_a3it_2a2z  :@computed_region_8spj_utxs  \
# 0                       3256.0                          3.0
# 1                       3258.0                          2.0
# 2                       3256.0                          3.0
# 3                       3646.0                          4.0
# 4                       3258.0                          2.0
#
#   :@computed_region_q9nd_rr82 ucr_category  category_description  \
# 0                         3.0          NaN                   NaN
# 1                         4.0          220              Burglary
# 2                         3.0          NaN                   NaN
# 3                         9.0          13A    Aggravated Assault
# 4                         4.0          NaN                   NaN
#
#    :@computed_region_qwte_z96m  clearance_status  clearance_date
# 0                          NaN               NaN             NaN
# 1                       2268.0               NaN             NaN
# 2                       1599.0               NaN             NaN
# 3                       3851.0               NaN             NaN
# 4                          NaN               NaN             NaN
#
# [5 rows x 31 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_report_number       500000 non-null  int64
#  1   crime_type                   500000 non-null  object
#  2   ucr_code                     500000 non-null  int64
#  3   family_violence              500000 non-null  object
#  4   occ_date_time                500000 non-null  object
#  5   occ_date                     500000 non-null  object
#  6   occ_time                     500000 non-null  int64
#  7   rep_date_time                500000 non-null  object
#  8   rep_date                     500000 non-null  object
#  9   rep_time                     500000 non-null  int64
#  10  location_type                498336 non-null  object
#  11  address                      500000 non-null  object
#  12  zip_code                     497118 non-null  float64
#  13  council_district             494792 non-null  float64
#  14  sector                       498366 non-null  object
#  15  district                     498224 non-null  object
#  16  pra                          497709 non-null  float64
#  17  census_tract                 495816 non-null  float64
#  18  x_coordinate                 497855 non-null  float64
#  19  y_coordinate                 497855 non-null  float64
#  20  latitude                     490957 non-null  float64
#  21  longitude                    490957 non-null  float64
#  22  location                     490957 non-null  object
#  23  :@computed_region_a3it_2a2z  490952 non-null  float64
#  24  :@computed_region_8spj_utxs  488726 non-null  float64
#  25  :@computed_region_q9nd_rr82  489772 non-null  float64
#  26  ucr_category                 190835 non-null  object
#  27  category_description         190835 non-null  object
#  28  :@computed_region_qwte_z96m  272371 non-null  float64
#  29  clearance_status             440652 non-null  object
#  30  clearance_date               440639 non-null  object
# dtypes: float64(12), int64(4), object(15)
# memory usage: 118.3+ MB

# %%
df2.incident_report_number.nunique()
# Out:
# 500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_report_number       500000 non-null  int64
#  1   crime_type                   500000 non-null  object
#  2   ucr_code                     500000 non-null  int64
#  3   family_violence              500000 non-null  object
#  4   occ_date_time                500000 non-null  object
#  5   occ_date                     500000 non-null  object
#  6   occ_time                     500000 non-null  int64
#  7   rep_date_time                500000 non-null  object
#  8   rep_date                     500000 non-null  object
#  9   rep_time                     500000 non-null  int64
#  10  location_type                498336 non-null  object
#  11  address                      500000 non-null  object
#  12  zip_code                     497118 non-null  float64
#  13  council_district             494792 non-null  float64
#  14  sector                       498366 non-null  object
#  15  district                     498224 non-null  object
#  16  pra                          497709 non-null  float64
#  17  census_tract                 495816 non-null  float64
#  18  x_coordinate                 497855 non-null  float64
#  19  y_coordinate                 497855 non-null  float64
#  20  latitude                     490957 non-null  float64
#  21  longitude                    490957 non-null  float64
#  22  location                     490957 non-null  object
#  23  :@computed_region_a3it_2a2z  490952 non-null  float64
#  24  :@computed_region_8spj_utxs  488726 non-null  float64
#  25  :@computed_region_q9nd_rr82  489772 non-null  float64
#  26  ucr_category                 190835 non-null  object
#  27  category_description         190835 non-null  object
#  28  :@computed_region_qwte_z96m  272371 non-null  float64
#  29  clearance_status             440652 non-null  object
#  30  clearance_date               440639 non-null  object
# dtypes: float64(12), int64(4), object(15)
# memory usage: 118.3+ MB

# %% [markdown]
# ## Limiting Time Frame
# **We decided to limit the time frame of data to improve relevancy and workability.**

# %%
df.head(1).occ_date
# Out:
# 0    2022-05-28T00:00:00.000
# Name: occ_date, dtype: object

# %%
# Let's change the data times to the correct data type
#df.occ_date = pd.to_datetime(df.occ_date, format = '%Y-%m-%d')

# %%
# Let's limit our time frame to 2018 - 2021
#df = df[(df.occ_date >= '2018-01-01') & (df.occ_date <= '2021-12-31')]
df.shape
# Out:
# (500000, 31)

# %% [markdown]
# ## Handling Nulls

# %%
# Let's look at nulls now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_report_number       500000 non-null  int64
#  1   crime_type                   500000 non-null  object
#  2   ucr_code                     500000 non-null  int64
#  3   family_violence              500000 non-null  object
#  4   occ_date_time                500000 non-null  object
#  5   occ_date                     500000 non-null  object
#  6   occ_time                     500000 non-null  int64
#  7   rep_date_time                500000 non-null  object
#  8   rep_date                     500000 non-null  object
#  9   rep_time                     500000 non-null  int64
#  10  location_type                498336 non-null  object
#  11  address                      500000 non-null  object
#  12  zip_code                     497118 non-null  float64
#  13  council_district             494792 non-null  float64
#  14  sector                       498366 non-null  object
#  15  district                     498224 non-null  object
#  16  pra                          497709 non-null  float64
#  17  census_tract                 495816 non-null  float64
#  18  x_coordinate                 497855 non-null  float64
#  19  y_coordinate                 497855 non-null  float64
#  20  latitude                     490957 non-null  float64
#  21  longitude                    490957 non-null  float64
#  22  location                     490957 non-null  object
#  23  :@computed_region_a3it_2a2z  490952 non-null  float64
#  24  :@computed_region_8spj_utxs  488726 non-null  float64
#  25  :@computed_region_q9nd_rr82  489772 non-null  float64
#  26  ucr_category                 190835 non-null  object
#  27  category_description         190835 non-null  object
#  28  :@computed_region_qwte_z96m  272371 non-null  float64
#  29  clearance_status             440652 non-null  object
#  30  clearance_date               440639 non-null  object
# dtypes: float64(12), int64(4), object(15)
# memory usage: 118.3+ MB

# %%
prep.attribute_nulls(df)
# Out:
#                              rows_missing  percent_missing
# incident_report_number                  0         0.000000
# crime_type                              0         0.000000
# ucr_code                                0         0.000000
# family_violence                         0         0.000000
# occ_date_time                           0         0.000000
# occ_date                                0         0.000000
# occ_time                                0         0.000000
# rep_date_time                           0         0.000000
# rep_date                                0         0.000000
# rep_time                                0         0.000000
# location_type                        1664         0.003328
# address                                 0         0.000000
# zip_code                             2882         0.005764
# council_district                     5208         0.010416
# sector                               1634         0.003268
# district                             1776         0.003552
# pra                                  2291         0.004582
# census_tract                         4184         0.008368
# x_coordinate                         2145         0.004290
# y_coordinate                         2145         0.004290
# latitude                             9043         0.018086
# longitude                            9043         0.018086
# location                             9043         0.018086
# :@computed_region_a3it_2a2z          9048         0.018096
# :@computed_region_8spj_utxs         11274         0.022548
# :@computed_region_q9nd_rr82         10228         0.020456
# ucr_category                       309165         0.618330
# category_description               309165         0.618330
# :@computed_region_qwte_z96m        227629         0.455258
# clearance_status                    59348         0.118696
# clearance_date                      59361         0.118722

# %%
df.family_violence.value_counts(dropna=False)
# Out:
# N    462457
# Y     37543
# Name: family_violence, dtype: int64

# %%
df.head()
# Out:
#    incident_report_number             crime_type  ucr_code family_violence  \
# 0             20221481617     FAMILY DISTURBANCE      3400               N
# 1             20221481526  BURGLARY OF RESIDENCE       500               Y
# 2             20221481586                    DWI      2100               N
# 3             20221481541            AGG ASSAULT       402               N
# 4             20221481449     FAMILY DISTURBANCE      3400               N
#
#              occ_date_time                 occ_date  occ_time  \
# 0  2022-05-28T23:34:00.000  2022-05-28T00:00:00.000      2334
# 1  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312
# 2  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312
# 3  2022-05-28T22:37:00.000  2022-05-28T00:00:00.000      2237
# 4  2022-05-28T22:34:00.000  2022-05-28T00:00:00.000      2234
#
#              rep_date_time                 rep_date  rep_time  ...  longitude  \
# 0  2022-05-28T23:34:00.000  2022-05-28T00:00:00.000      2334  ... -97.693064
# 1  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312  ... -97.735209
# 2  2022-05-28T23:12:00.000  2022-05-28T00:00:00.000      2312  ... -97.713580
# 3  2022-05-28T22:37:00.000  2022-05-28T00:00:00.000      2237  ... -97.703725
# 4  2022-05-28T22:34:00.000  2022-05-28T00:00:00.000      2234  ... -97.747848
#
#                                             location  \
# 0  {'latitude': '30.24071184', 'longitude': '-97....
# 1  {'latitude': '30.1996283', 'longitude': '-97.7...
# 2  {'latitude': '30.24610845', 'longitude': '-97....
# 3  {'latitude': '30.36871033', 'longitude': '-97....
# 4  {'latitude': '30.19838244', 'longitude': '-97....
#
#    :@computed_region_a3it_2a2z  :@computed_region_8spj_utxs  \
# 0                       3256.0                          3.0
# 1                       3258.0                          2.0
# 2                       3256.0                          3.0
# 3                       3646.0                          4.0
# 4                       3258.0                          2.0
#
#   :@computed_region_q9nd_rr82 ucr_category  category_description  \
# 0                         3.0          NaN                   NaN
# 1                         4.0          220              Burglary
# 2                         3.0          NaN                   NaN
# 3                         9.0          13A    Aggravated Assault
# 4                         4.0          NaN                   NaN
#
#    :@computed_region_qwte_z96m  clearance_status  clearance_date
# 0                          NaN               NaN             NaN
# 1                       2268.0               NaN             NaN
# 2                       1599.0               NaN             NaN
# 3                       3851.0               NaN             NaN
# 4                          NaN               NaN             NaN
#
# [5 rows x 31 columns]

# %%
df = prep.prep_data(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349581 entries, 34573 to 436548
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   crime_type        349581 non-null  object
#  1   family_violence   349581 non-null  object
#  2   occurrence_time   349581 non-null  datetime64[ns]
#  3   occurrence_date   349581 non-null  datetime64[ns]
#  4   report_time       349581 non-null  datetime64[ns]
#  5   report_date       349581 non-null  datetime64[ns]
#  6   location_type     349581 non-null  object
#  7   address           349581 non-null  object
#  8   zip_code          349581 non-null  float64
#  9   council_district  349581 non-null  float64
#  10  sector            349581 non-null  object
#  11  district          349581 non-null  object
#  12  latitude          349581 non-null  float64
#  13  longitude         349581 non-null  float64
#  14  clearance_status  349581 non-null  object
#  15  clearance_date    349581 non-null  datetime64[ns]
#  16  cleared           349581 non-null  bool
#  17  time_to_report    349581 non-null  timedelta64[ns]
# dtypes: bool(1), datetime64[ns](5), float64(4), object(7), timedelta64[ns](1)
# memory usage: 48.3+ MB

# %%
df.info
# Out:
# <bound method DataFrame.info of                            crime_type family_violence     occurrence_time  \
# 34573       ASSAULT ON PUBLIC SERVANT               N 2021-12-31 23:50:00
# 34574                           THEFT               N 2021-12-31 23:50:00
# 34575             PUBLIC INTOXICATION               N 2021-12-31 23:50:00
# 34576   DOC DISCHARGE GUN - PUB PLACE               N 2021-12-31 23:47:00
# 34577     AGG ASLT STRANGLE/SUFFOCATE               Y 2021-12-31 23:40:00
# ...                               ...             ...                 ...
# 436544                          THEFT               N 2018-01-01 00:00:00
# 436545   POSS/PROMO CHILD PORNOGRAPHY               N 2018-01-01 00:00:00
# 436546                 IDENTITY THEFT               N 2018-01-01 00:00:00
# 436547                          THEFT               N 2018-01-01 00:00:00
# 436548                     HARASSMENT               N 2018-01-01 00:00:00
#
#        occurrence_date         report_time report_date  \
# 34573       2021-12-31 2021-12-31 23:50:00  2021-12-31
# 34574       2021-12-31 2022-01-07 14:12:00  2022-01-07
# 34575       2021-12-31 2021-12-31 23:50:00  2021-12-31
# 34576       2021-12-31 2021-12-31 23:47:00  2021-12-31
# 34577       2021-12-31 2022-01-01 00:44:00  2022-01-01
# ...                ...                 ...         ...
# 436544      2018-01-01 2018-02-11 19:17:00  2018-02-11
# 436545      2018-01-01 2018-09-07 21:30:00  2018-09-07
# 436546      2018-01-01 2022-03-30 19:47:00  2022-03-30
# 436547      2018-01-01 2018-07-24 15:43:00  2018-07-24
# 436548      2018-01-01 2018-06-12 20:33:00  2018-06-12
#
#                                location_type                        address  \
# 34573           COMMERCIAL / OFFICE BUILDING               111 CONGRESS AVE
# 34574                        OTHER / UNKNOWN  6936 E BEN WHITE BLVD SVRD WB
# 34575   HWY / ROAD / ALLEY/ STREET/ SIDEWALK                   406 E 6TH ST
# 34576                       RESIDENCE / HOME            1202 E ST JOHNS AVE
# 34577                       RESIDENCE / HOME             10000 N LAMAR BLVD
# ...                                      ...                            ...
# 436544                      RESIDENCE / HOME           8838 HONEYSUCKLE TRL
# 436545                       OTHER / UNKNOWN             10804 CHATEAU HILL
# 436546                      RESIDENCE / HOME             1115 TOWN CREEK DR
# 436547             PARKING /DROP LOT/ GARAGE         1030 NORWOOD PARK BLVD
# 436548                      RESIDENCE / HOME             420 W SLAUGHTER LN
#
#         zip_code  council_district sector district   latitude  longitude  \
# 34573    78701.0               9.0     GE        3  30.263739 -97.743651
# 34574    78741.0               3.0     HE        5  30.215264 -97.703019
# 34575    78701.0               9.0     GE        2  30.267300 -97.738857
# 34576    78752.0               4.0     ID        1  30.328049 -97.693683
# 34577    78758.0               4.0     ED        1  30.369262 -97.695105
# ...          ...               ...    ...      ...        ...        ...
# 436544   78759.0              10.0     BA        8  30.380626 -97.743507
# 436545   78750.0               6.0     AD        8  30.432467 -97.800260
# 436546   78741.0               3.0     HE        2  30.244328 -97.725245
# 436547   78753.0               4.0     ID        2  30.339152 -97.691166
# 436548   78748.0               2.0     FR        3  30.172125 -97.797176
#
#          clearance_status clearance_date  cleared     time_to_report
# 34573   cleared by arrest     2022-01-03     True    0 days 00:00:00
# 34574         not cleared     2022-01-10    False    6 days 14:22:00
# 34575   cleared by arrest     2021-12-31     True    0 days 00:00:00
# 34576         not cleared     2022-01-05    False    0 days 00:00:00
# 34577         not cleared     2022-01-05    False    0 days 01:04:00
# ...                   ...            ...      ...                ...
# 436544        not cleared     2018-02-12    False   41 days 19:17:00
# 436545        not cleared     2019-10-09    False  249 days 21:30:00
# 436546        not cleared     2022-04-19    False 1549 days 19:47:00
# 436547        not cleared     2018-07-25    False  204 days 15:43:00
# 436548        not cleared     2018-06-13    False  162 days 20:33:00
#
# [349581 rows x 18 columns]>

# %%
# Use .describe with object columns
obj_cols = df.columns[[df[col].dtype == 'O' for col in df.columns]]
obj_cols

for col in obj_cols:
    print(col.upper())
    print('Count:')
    print(df[col].value_counts())
    print('\n')
    print('Proportions:')
    print(df[col].value_counts(normalize=True, dropna=False))
    print('--------------------------')
    print('\n')
# Out:
# CRIME_TYPE
# Count:
# BURGLARY OF VEHICLE               34886
# THEFT                             29943
# FAMILY DISTURBANCE                24386
# CRIMINAL MISCHIEF                 19382
# ASSAULT W/INJURY-FAM/DATE VIOL    12857
#                                   ...
# COMMERCIAL BRIBERY                    1
# ATT BURGLARY OF RESIDENCE             1
# SALE OF DXM TO MINOR                  1
# MANF SYNTHETIC MARIJUANA              1
# BAIL JUMPING/FAIL TO APPEAR           1
# Name: crime_type, Length: 341, dtype: int64
#
#
# Proportions:
# BURGLARY OF VEHICLE               0.099794
# THEFT                             0.085654
# FAMILY DISTURBANCE                0.069758
# CRIMINAL MISCHIEF                 0.055444
# ASSAULT W/INJURY-FAM/DATE VIOL    0.036778
#                                     ...
# COMMERCIAL BRIBERY                0.000003
# ATT BURGLARY OF RESIDENCE         0.000003
# SALE OF DXM TO MINOR              0.000003
# MANF SYNTHETIC MARIJUANA          0.000003
# BAIL JUMPING/FAIL TO APPEAR       0.000003
# Name: crime_type, Length: 341, dtype: float64
# --------------------------
#
#
# FAMILY_VIOLENCE
# Count:
# N    321418
# Y     28163
# Name: family_violence, dtype: int64
#
#
# Proportions:
# N    0.919438
# Y    0.080562
# Name: family_violence, dtype: float64
# --------------------------
#
#
# LOCATION_TYPE
# Count:
# RESIDENCE / HOME                                   139468
# HWY / ROAD / ALLEY/ STREET/ SIDEWALK                58705
# PARKING /DROP LOT/ GARAGE                           45334
# OTHER / UNKNOWN                                     25920
# COMMERCIAL / OFFICE BUILDING                         9717
# HOTEL / MOTEL / ETC.                                 7820
# DEPARTMENT / DISCOUNT STORE                          7677
# RESTAURANT                                           7105
# GROCERY / SUPERMARKET                                5988
# CONVENIENCE STORE                                    5449
# SERVICE/ GAS STATION                                 5064
# DRUG STORE / DOCTOR'S OFFICE / HOSPITAL              4114
# BAR / NIGHTCLUB                                      3966
# PARK / PLAYGROUND                                    3145
# SPECIALTY  STORE                                     2949
# AIR / BUS / TRAIN TERMINAL                           2411
# GOVERNMENT / PUBLIC BUILDING                         1570
# CONSTRUCTION SITE                                    1568
# BANK / SAVINGS & LOAN                                1560
# RENTAL STORAGE FACILITY                              1479
# LIQUOR STORE                                         1061
# SHOPPING MALL                                         981
# AUTO DEALERSHIP NEW / USED                            889
# CHURCH / SYNAGOGUE / TEMPLE / MOSQUE                  802
# ABANDONED/CONDEMNED STRUCTURE                         698
# SHELTER-MISSION / HOMELESS                            678
# FIELD / WOODS                                         641
# SCHOOL - ELEMENTARY / SECONDARY                       559
# COMMUNITY CENTER                                      355
# SCHOOL - COLLEGE / UNIVERSITY                         309
# DAYCARE FACILITY                                      223
# SCHOOL / COLLEGE                                      204
# CAMP / CAMPGROUND                                     196
# JAIL / PRISON/PENITENTIARY/CORRECTIONS FACILITY       163
# GAMBLING FACILITY / CASINO / RACE TRACK               138
# ATM SEPARATE FROM BANK                                136
# LAKE / WATERWAY/BEACH                                 122
# CYBERSPACE                                            122
# INDUSTRIAL SITE                                       102
# ARENA / STADIUM / FAIRGROUNDS / COLISEUM               67
# AMUSEMENT PARK                                         46
# REST AREA                                              46
# DOCK / WHARF / FREIGHT / MODAL TERMINAL                25
# MILITARY INSTALLATION                                   3
# FARM FACILITY                                           3
# TRIBAL LANDS                                            3
# Name: location_type, dtype: int64
#
#
# Proportions:
# RESIDENCE / HOME                                   0.398958
# HWY / ROAD / ALLEY/ STREET/ SIDEWALK               0.167930
# PARKING /DROP LOT/ GARAGE                          0.129681
# OTHER / UNKNOWN                                    0.074146
# COMMERCIAL / OFFICE BUILDING                       0.027796
# HOTEL / MOTEL / ETC.                               0.022370
# DEPARTMENT / DISCOUNT STORE                        0.021961
# RESTAURANT                                         0.020324
# GROCERY / SUPERMARKET                              0.017129
# CONVENIENCE STORE                                  0.015587
# SERVICE/ GAS STATION                               0.014486
# DRUG STORE / DOCTOR'S OFFICE / HOSPITAL            0.011768
# BAR / NIGHTCLUB                                    0.011345
# PARK / PLAYGROUND                                  0.008996
# SPECIALTY  STORE                                   0.008436
# AIR / BUS / TRAIN TERMINAL                         0.006897
# GOVERNMENT / PUBLIC BUILDING                       0.004491
# CONSTRUCTION SITE                                  0.004485
# BANK / SAVINGS & LOAN                              0.004462
# RENTAL STORAGE FACILITY                            0.004231
# LIQUOR STORE                                       0.003035
# SHOPPING MALL                                      0.002806
# AUTO DEALERSHIP NEW / USED                         0.002543
# CHURCH / SYNAGOGUE / TEMPLE / MOSQUE               0.002294
# ABANDONED/CONDEMNED STRUCTURE                      0.001997
# SHELTER-MISSION / HOMELESS                         0.001939
# FIELD / WOODS                                      0.001834
# SCHOOL - ELEMENTARY / SECONDARY                    0.001599
# COMMUNITY CENTER                                   0.001016
# SCHOOL - COLLEGE / UNIVERSITY                      0.000884
# DAYCARE FACILITY                                   0.000638
# SCHOOL / COLLEGE                                   0.000584
# CAMP / CAMPGROUND                                  0.000561
# JAIL / PRISON/PENITENTIARY/CORRECTIONS FACILITY    0.000466
# GAMBLING FACILITY / CASINO / RACE TRACK            0.000395
# ATM SEPARATE FROM BANK                             0.000389
# LAKE / WATERWAY/BEACH                              0.000349
# CYBERSPACE                                         0.000349
# INDUSTRIAL SITE                                    0.000292
# ARENA / STADIUM / FAIRGROUNDS / COLISEUM           0.000192
# AMUSEMENT PARK                                     0.000132
# REST AREA                                          0.000132
# DOCK / WHARF / FREIGHT / MODAL TERMINAL            0.000072
# MILITARY INSTALLATION                              0.000009
# FARM FACILITY                                      0.000009
# TRIBAL LANDS                                       0.000009
# Name: location_type, dtype: float64
# --------------------------
#
#
# ADDRESS
# Count:
# 4110 GUADALUPE ST                 1952
# 1030 NORWOOD PARK BLVD            1247
# 3600 PRESIDENTIAL BLVD            1190
# 500 E 7TH ST                       938
# 2901 S CAPITAL OF TEXAS HWY NB     865
#                                   ...
# 7001 SCENIC BROOK DR                 1
# 706 MERIDEN LN                       1
# 500 BLOCK W 5TH ST                   1
# 3203 MOSSROCK DR                     1
# 8838 HONEYSUCKLE TRL                 1
# Name: address, Length: 78977, dtype: int64
#
#
# Proportions:
# 4110 GUADALUPE ST                 0.005584
# 1030 NORWOOD PARK BLVD            0.003567
# 3600 PRESIDENTIAL BLVD            0.003404
# 500 E 7TH ST                      0.002683
# 2901 S CAPITAL OF TEXAS HWY NB    0.002474
#                                     ...
# 7001 SCENIC BROOK DR              0.000003
# 706 MERIDEN LN                    0.000003
# 500 BLOCK W 5TH ST                0.000003
# 3203 MOSSROCK DR                  0.000003
# 8838 HONEYSUCKLE TRL              0.000003
# Name: address, Length: 78977, dtype: float64
# --------------------------
#
#
# SECTOR
# Count:
# ED    49924
# DA    45178
# FR    42716
# AD    41948
# BA    37501
# CH    36176
# HE    36079
# ID    35666
# GE    21758
# AP     1879
# 88      612
# UT      144
# Name: sector, dtype: int64
#
#
# Proportions:
# ED    0.142811
# DA    0.129235
# FR    0.122192
# AD    0.119995
# BA    0.107274
# CH    0.103484
# HE    0.103206
# ID    0.102025
# GE    0.062240
# AP    0.005375
# 88    0.001751
# UT    0.000412
# Name: sector, dtype: float64
# --------------------------
#
#
# DISTRICT
# Count:
# 2     69359
# 1     65474
# 3     42596
# 4     42188
# 5     35701
# 7     34736
# 6     33232
# 8     23643
# S      1280
# 88      612
# D       391
# B       122
# A       119
# P        94
# C        34
# Name: district, dtype: int64
#
#
# Proportions:
# 2     0.198406
# 1     0.187293
# 3     0.121849
# 4     0.120682
# 5     0.102125
# 7     0.099365
# 6     0.095062
# 8     0.067632
# S     0.003662
# 88    0.001751
# D     0.001118
# B     0.000349
# A     0.000340
# P     0.000269
# C     0.000097
# Name: district, dtype: float64
# --------------------------
#
#
# CLEARANCE_STATUS
# Count:
# not cleared             275577
# cleared by arrest        72431
# cleared by exception      1573
# Name: clearance_status, dtype: int64
#
#
# Proportions:
# not cleared             0.788307
# cleared by arrest       0.207194
# cleared by exception    0.004500
# Name: clearance_status, dtype: float64
# --------------------------

# %% [markdown]
# ## Univariate Exploration

# %%
# Start by looking at distributions
# ex.plot_distributions(df)

# %% [markdown]
# ## Split the Data

# %%
train, validate, test = prep.split_data(df, 'cleared')
train.shape, validate.shape, test.shape
# Out:
# ((195764, 18), (83900, 18), (69917, 18))

# %%
train.head()
# Out:
#                           crime_type family_violence     occurrence_time  \
# 128272                IDENTITY THEFT               N 2020-12-29 18:30:00
# 420369  POSS CONTROLLED SUB/NARCOTIC               N 2018-03-03 01:47:00
# 79483            BURGLARY OF VEHICLE               N 2021-07-05 00:00:00
# 430217    INTERFERENCE PUBLIC DUTIES               N 2018-01-25 17:24:00
# 280218           BURGLARY OF VEHICLE               N 2019-07-10 18:15:00
#
#        occurrence_date         report_time report_date  \
# 128272      2020-12-29 2020-12-30 01:46:00  2020-12-30
# 420369      2018-03-03 2018-03-03 01:47:00  2018-03-03
# 79483       2021-07-05 2021-07-06 19:54:00  2021-07-06
# 430217      2018-01-25 2018-01-31 17:24:00  2018-01-31
# 280218      2019-07-10 2019-07-11 09:49:00  2019-07-11
#
#                                location_type              address  zip_code  \
# 128272                      RESIDENCE / HOME         504 ARBOR LN   78745.0
# 420369  HWY / ROAD / ALLEY/ STREET/ SIDEWALK         404 E 6TH ST   78701.0
# 79483                       RESIDENCE / HOME     2200 PANTHER TRL   78704.0
# 430217  HWY / ROAD / ALLEY/ STREET/ SIDEWALK  2200 W SLAUGHTER LN   78748.0
# 280218             PARKING /DROP LOT/ GARAGE        121 PICKLE RD   78704.0
#
#         council_district sector district   latitude  longitude  \
# 128272               3.0     DA        3  30.210307 -97.779062
# 420369               9.0     GE        2  30.267321 -97.738933
# 79483                5.0     DA        4  30.237971 -97.786882
# 430217               5.0     FR        1  30.174079 -97.827130
# 280218               3.0     DA        2  30.227295 -97.763052
#
#          clearance_status clearance_date  cleared  time_to_report
# 128272        not cleared     2020-12-30    False 0 days 07:16:00
# 420369  cleared by arrest     2018-05-05     True 0 days 00:00:00
# 79483         not cleared     2021-07-15    False 1 days 19:54:00
# 430217  cleared by arrest     2018-01-31     True 6 days 00:00:00
# 280218        not cleared     2019-07-16    False 0 days 15:34:00

# %%
## Use probability to detect anomalies in our variables

for col in train.columns:
    plt.figure(figsize=(20, 15))
    splot = sns.barplot(x='index', y=col, data=train[col].value_counts(normalize=True).reset_index().sort_values(
        by=col, ascending=False).head(10))
    for p in splot.patches:
        splot.annotate(format(p.get_height() * 100, '.1f') + ' %', 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   xytext = (0, 8), 
                   textcoords = 'offset points')
    plt.title(col.title())
    plt.ylabel('probability')
    plt.show()

# %% [markdown]
# ## Exploration
#
# ### Initial Questions to Answer
#
# 1. Which types/categories of crime are not getting solved/closed?
# - After MVP, possibly drill down into specific crime descriptions.
# 2. Are there certain city council districts with disproportionate levels of crime?
# 3. Is crime seasonal? Times of the year when a crime is more prevalent?
# 4. Does the difference between time of incident and report time relate to a crime being solved/closed?

# %% [markdown]
# #### I'll take a quick look at feature correlation with our target variable

# %%
# Checking assessed_value correlation vs all variables

ex.plot_correlations(train)

# %%
# Simple heatmap
sns.heatmap(train.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Moving into multivariate exploration for my question.**
#
# ## Question 1: Which types/categories of crime are not getting solved/closed?
#
# $H0$: Type of crime and clearance are independent of eachother.
#
# $Ha$: Type of crime and and clearance are dependent on eachother.
#
# #### Statistical Testing
#
# *Setting my confidence level at 95% which makes my alpha = .05*

# %%
target = train.cleared
ex.chi2(train.crime_type, target)
# Out:
# The chi2 value between the two variables is 102967.85678373862 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %% [markdown]
# **A Chi^2 establishes that there is a statistically signifiant dependency.**
#
# #### Visualizations

# %%
sns.barplot(x='crime_type', y='cleared', data= train)
# Out:
# <AxesSubplot:xlabel='crime_type', ylabel='cleared'>

# %%
# create  --- This seems like a wrong way to visualize
train.crime_type.value_counts().plot(kind='pie', y='cleared', autopct="%1.1f%%")
# remove y axis label
plt.ylabel(None)
#add title
plt.title('Top Crimes as Percentage of Overall Crime Rate in Subset')
plt.show()

# %% [markdown]
# **There are too many unique crime types to make sense of this. For a first iteration, I will need to only look at rows that fall within a certain threshold of observations to reduce the values I'm looking at. I'll create a function to check value_counts and frequencies that will help decide what that threshold should be. On another iteration, I may also try changing crime types that don't meet a threshold into an 'Other' value.**

# %%
def value_counts_and_frequencies(s: pd.Series, dropna=True) -> pd.DataFrame:
    return pd.merge(
        s.value_counts(dropna=False).rename('count'),
        s.value_counts(dropna=False, normalize=True).rename('proba'),
        left_index=True,
        right_index=True,
    )

# %%
crime_type_df = value_counts_and_frequencies(train.crime_type)
crime_type_df
# Out:
#                                 count     proba
# BURGLARY OF VEHICLE             19462  0.099416
# THEFT                           16814  0.085889
# FAMILY DISTURBANCE              13596  0.069451
# CRIMINAL MISCHIEF               10912  0.055741
# ASSAULT W/INJURY-FAM/DATE VIOL   7165  0.036600
# ...                               ...       ...
# CRIMINAL CONSPIRACY                 1  0.000005
# DOC CREATING NOXIOUS ODOR           1  0.000005
# FALSE ID AS A PEACE OFFICER         1  0.000005
# VIOL CITY ORDINANCE - CURFEW        1  0.000005
# BAIL JUMPING/FAIL TO APPEAR         1  0.000005
#
# [322 rows x 2 columns]

# %%
# Let's visualize the top 5 crime types
crime_type_df['count'].sort_values().tail(5).plot.barh(figsize=(5, 9))
# Out:
# <AxesSubplot:>

# %%
crime_type_df.tail(30)
# Out:
#                                 count     proba
# THEFT BY PUBLIC SERVANT             2  0.000010
# BANK KITING                         1  0.000005
# DISRUPTIVE ACTS AT SCHOOLS          1  0.000005
# FIREARMS ON SCHOOL PROP             1  0.000005
# OFFICIAL MISCONDUCT                 1  0.000005
# VOCO AMPLIFIED MUSIC/VEHICLE        1  0.000005
# COMMERCIAL BRIBERY                  1  0.000005
# ATT BURGLARY OF RESIDENCE           1  0.000005
# BRIBERY                             1  0.000005
# MANF CONTROLLED SUB - OTHER         1  0.000005
# FALSE REPORT TO CPS                 1  0.000005
# MANF SYNTHETIC MARIJUANA            1  0.000005
# CRIM NEG HOMICIDE/NON TRAFFIC       1  0.000005
# VIOL STAY AWAY ORDER                1  0.000005
# BESTIALITY                          1  0.000005
# THEFT OF TELECOMMUNICATION SRV      1  0.000005
# DEL OF ALCOHOL TO MINOR             1  0.000005
# INJURY TO ELDERLY PERSON - SBI      1  0.000005
# BOATING WHILE INTOXICATED           1  0.000005
# IMMIGRATION HOLD/ARREST             1  0.000005
# FALSE CALLER ID DISPLAY/SPOOF       1  0.000005
# VIOL CITY ORDINANCE - TAXI          1  0.000005
# CRASH/CRIM NEG HOMICIDE             1  0.000005
# VIOL OF OBSTRUCTION ORDINANCE       1  0.000005
# FICTITIOUS NAME                     1  0.000005
# CRIMINAL CONSPIRACY                 1  0.000005
# DOC CREATING NOXIOUS ODOR           1  0.000005
# FALSE ID AS A PEACE OFFICER         1  0.000005
# VIOL CITY ORDINANCE - CURFEW        1  0.000005
# BAIL JUMPING/FAIL TO APPEAR         1  0.000005

# %% [markdown]
# **We have quite a lot of crime types with only 1 observation. Let's look at how many crime types there are when we only look at types with more than 50 observations.**

# %%
crime_type_df[crime_type_df['count'] >= 50]
# Out:
#                                 count     proba
# BURGLARY OF VEHICLE             19462  0.099416
# THEFT                           16814  0.085889
# FAMILY DISTURBANCE              13596  0.069451
# CRIMINAL MISCHIEF               10912  0.055741
# ASSAULT W/INJURY-FAM/DATE VIOL   7165  0.036600
# ...                               ...       ...
# FEDERAL VIOL/OTHER                 57  0.000291
# POSS DANG DRUG                     56  0.000286
# UNLAWFUL RESTRAINT FAM/DAT VIO     55  0.000281
# CRIMINAL MISCHIEF BY ARSON         52  0.000266
# DOC UNREASONABLE NOISE             50  0.000255
#
# [141 rows x 2 columns]

# %% [markdown]
# *We still have 143 different crime types. Next, I'll try setting the threshold to 200.*

# %%
crime_type_df[crime_type_df['count'] >= 200]
# Out:
#                                 count     proba
# BURGLARY OF VEHICLE             19462  0.099416
# THEFT                           16814  0.085889
# FAMILY DISTURBANCE              13596  0.069451
# CRIMINAL MISCHIEF               10912  0.055741
# ASSAULT W/INJURY-FAM/DATE VIOL   7165  0.036600
# ...                               ...       ...
# ROBBERY BY THREAT                 212  0.001083
# RESISTING ARREST OR SEARCH        211  0.001078
# DOC EXPOSURE                      205  0.001047
# DWI - DRUG RECOGNITION EXPERT     201  0.001027
# PUBLIC INTOX-SOBERING CENTER      200  0.001022
#
# [85 rows x 2 columns]

# %% [markdown]
# *88 crime typs is still too many to visualize. Let's try 1000 observations as the threshold.*

# %%
crime_type_df[crime_type_df['count'] >= 1000]
# Out:
#                                                count     proba
# BURGLARY OF VEHICLE                            19462  0.099416
# THEFT                                          16814  0.085889
# FAMILY DISTURBANCE                             13596  0.069451
# CRIMINAL MISCHIEF                              10912  0.055741
# ASSAULT W/INJURY-FAM/DATE VIOL                  7165  0.036600
# AUTO THEFT                                      7158  0.036564
# HARASSMENT                                      5808  0.029668
# THEFT BY SHOPLIFTING                            5727  0.029255
# ASSAULT WITH INJURY                             5469  0.027937
# DWI                                             4360  0.022272
# BURGLARY OF RESIDENCE                           4194  0.021424
# BURGLARY NON RESIDENCE                          4065  0.020765
# ASSAULT BY CONTACT                              3733  0.019069
# CRIMINAL TRESPASS                               3596  0.018369
# IDENTITY THEFT                                  3413  0.017434
# POSS CONTROLLED SUB/NARCOTIC                    3320  0.016959
# DISTURBANCE - OTHER                             3279  0.016750
# THEFT OF BICYCLE                                3073  0.015697
# RUNAWAY CHILD                                   2988  0.015263
# BURGLARY OF VEH-NO SUSPECT/FU                   2845  0.014533
# FRAUD - OTHER                                   2655  0.013562
# ASSAULT BY THREAT                               2455  0.012541
# POSSESSION OF MARIJUANA                         2192  0.011197
# AGG ASSAULT                                     2092  0.010686
# PUBLIC INTOXICATION                             2062  0.010533
# CHILD CUSTODY INTERFERE                         1948  0.009951
# ASSAULT BY CONTACT FAM/DATING                   1784  0.009113
# CRED CARD ABUSE - OTHER                         1752  0.008950
# DEBIT CARD ABUSE                                1722  0.008796
# POSS OF DRUG PARAPHERNALIA                      1592  0.008132
# MAIL THEFT                                      1592  0.008132
# TERRORISTIC THREAT                              1516  0.007744
# THEFT OF LICENSE PLATE                          1473  0.007524
# CRASH/FAIL STOP AND RENDER AID                  1387  0.007085
# DATING DISTURBANCE                              1381  0.007054
# AGG ASLT STRANGLE/SUFFOCATE                     1307  0.006676
# BURGLARY OF SHED/DETACHED GARAGE/STORAGE UNIT   1291  0.006595
# AGG ROBBERY/DEADLY WEAPON                       1284  0.006559
# THEFT CATALYTIC CONVERTER                       1269  0.006482
# FORGERY AND PASSING                             1210  0.006181
# THEFT FROM PERSON                               1094  0.005588

# %% [markdown]
# *There's still 42 which is too many to visualize.*
#
# **I think instead of a threshold, I'll limit crime types to the top 10.**

# %%
# Let's visualize the top 10 crime types
crime_type_df['count'].sort_values().tail(10).plot.barh(figsize=(5, 9))
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Let me use this to create a list of my top 10 crime types to use for visualizations using the train split.**

# %%
crime_type_df['count'].sort_values().tail(10)
# Out:
# DWI                                4360
# ASSAULT WITH INJURY                5469
# THEFT BY SHOPLIFTING               5727
# HARASSMENT                         5808
# AUTO THEFT                         7158
# ASSAULT W/INJURY-FAM/DATE VIOL     7165
# CRIMINAL MISCHIEF                 10912
# FAMILY DISTURBANCE                13596
# THEFT                             16814
# BURGLARY OF VEHICLE               19462
# Name: count, dtype: int64

# %%
# Create a list with the top 10 crimes
top_10_crimes = ['DWI', 'ASSAULT WITH INJURY', 'THEFT BY SHOPLIFTING', 'HARASSMENT', 
                 'AUTO THEFT', 'ASSAULT W/INJURY-FAM/DATE VIOL', 'CRIMINAL MISCHIEF', 
                 'FAMILY DISTURBANCE', 'THEFT', 'BURGLARY OF VEHICLE']

# %%
# Create a subsetted df that only includes the top 10 crimes
top_crimes_df = train.copy()
top_crimes_df = top_crimes_df[top_crimes_df.crime_type.isin(top_10_crimes)]
top_crimes_df.head()
# Out:
#                  crime_type family_violence     occurrence_time  \
# 79483   BURGLARY OF VEHICLE               N 2021-07-05 00:00:00
# 280218  BURGLARY OF VEHICLE               N 2019-07-10 18:15:00
# 435433    CRIMINAL MISCHIEF               N 2018-01-05 08:00:00
# 235833  BURGLARY OF VEHICLE               N 2019-12-06 16:20:00
# 289996  BURGLARY OF VEHICLE               N 2019-06-07 12:00:00
#
#        occurrence_date         report_time report_date  \
# 79483       2021-07-05 2021-07-06 19:54:00  2021-07-06
# 280218      2019-07-10 2019-07-11 09:49:00  2019-07-11
# 435433      2018-01-05 2018-01-05 15:46:00  2018-01-05
# 235833      2019-12-06 2019-12-07 08:01:00  2019-12-07
# 289996      2019-06-07 2019-06-11 16:29:00  2019-06-11
#
#                     location_type            address  zip_code  \
# 79483            RESIDENCE / HOME   2200 PANTHER TRL   78704.0
# 280218  PARKING /DROP LOT/ GARAGE      121 PICKLE RD   78704.0
# 435433              FIELD / WOODS  6600 ELM CREEK DR   78744.0
# 235833  PARKING /DROP LOT/ GARAGE   5206 BALCONES DR   78731.0
# 289996           RESIDENCE / HOME  7224 NORTHEAST DR   78723.0
#
#         council_district sector district   latitude  longitude  \
# 79483                5.0     DA        4  30.237971 -97.786882
# 280218               3.0     DA        2  30.227295 -97.763052
# 435433               2.0     FR        8  30.187399 -97.763642
# 235833              10.0     BA        7  30.334509 -97.759809
# 289996               1.0     ID        3  30.321613 -97.680093
#
#        clearance_status clearance_date  cleared  time_to_report
# 79483       not cleared     2021-07-15    False 1 days 19:54:00
# 280218      not cleared     2019-07-16    False 0 days 15:34:00
# 435433      not cleared     2018-01-09    False 0 days 07:46:00
# 235833      not cleared     2019-12-09    False 0 days 15:41:00
# 289996      not cleared     2019-06-12    False 4 days 04:29:00

# %%
# Sanity check
top_crimes_df.crime_type.value_counts().sum()
# Out:
# 96471

# %%
## Set up df so that crime_types are sorted correctly
top_crimes_df = top_crimes_df.sort_values(by='cleared', ascending=False)

# %% [markdown]
# **Now let me use this df to visualize the top 10 crime types.**

# %%
# create  --- This seems like a wrong way to visualize
top_crimes_df.crime_type.value_counts().plot(kind='pie', y='cleared', autopct="%1.1f%%")
# remove y axis label
plt.ylabel(None)
#add title
plt.title('Top 10 Crimes as Percentage of Overall Crime Rate in Subset')
plt.show()

# %%
top_crimes_df.crime_type.value_counts()
# Out:
# BURGLARY OF VEHICLE               19462
# THEFT                             16814
# FAMILY DISTURBANCE                13596
# CRIMINAL MISCHIEF                 10912
# ASSAULT W/INJURY-FAM/DATE VIOL     7165
# AUTO THEFT                         7158
# HARASSMENT                         5808
# THEFT BY SHOPLIFTING               5727
# ASSAULT WITH INJURY                5469
# DWI                                4360
# Name: crime_type, dtype: int64

# %% [markdown]
# **Let's visualize how crime type relates to clearance rate.**

# %%
# Calculate overall clearance rate
clearance_rate = train.cleared.mean()
clearance_rate
# Out:
# 0.2116936719723749

# %%
plt.title("Relationship Between Crime Type and Clearance Rate", fontsize=20)
top_crimes_df.groupby('crime_type').cleared.mean().sort_values(ascending=False).plot.bar()
plt.axhline(clearance_rate, label="Overall Clearance rate")
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Crime Type', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
None

# %%
top_crimes_df.groupby('crime_type').cleared.mean().sort_values(ascending=False)
# Out:
# crime_type
# DWI                               0.981422
# ASSAULT W/INJURY-FAM/DATE VIOL    0.600140
# THEFT BY SHOPLIFTING              0.231360
# AUTO THEFT                        0.158145
# ASSAULT WITH INJURY               0.115560
# THEFT                             0.105567
# CRIMINAL MISCHIEF                 0.047837
# FAMILY DISTURBANCE                0.036114
# BURGLARY OF VEHICLE               0.020245
# HARASSMENT                        0.012741
# Name: cleared, dtype: float64

# %%
plt.title("Relationship Between Crime Type and Clearance Rate", fontsize=20)
sns.barplot(x="crime_type", y="cleared", data=top_crimes_df,
            order=['DWI', 'ASSAULT W/INJURY-FAM/DATE VIOL', 'THEFT BY SHOPLIFTING', 'AUTO THEFT', 
                   'ASSAULT WITH INJURY', 'THEFT', 'CRIMINAL MISCHIEF', 'FAMILY DISTURBANCE', 
                   'BURGLARY OF VEHICLE', 'HARASSMENT'], color ='lightseagreen', ci=None)
plt.axhline(clearance_rate, label="Overall Clearance rate")
plt.ylabel('Clearance Rate', fontsize=13)
plt.xlabel('Crime Type', fontsize=13)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
plt.show()

# %%
def viz2(top_crimes_df, train):
    '''
    This fucntion will create a bar chart to visual the relationship between target and the features
    '''
    # Calculate overall clearance rate
    clearance_rate = train.cleared.mean()
    plt.title("Relationship Between Crime Type and Clearance Rate", fontsize=20)
    sns.barplot(x="cleared", y="crime_type", data=top_crimes_df,
            order=['DWI', 'ASSAULT W/INJURY-FAM/DATE VIOL', 'THEFT BY SHOPLIFTING', 'AUTO THEFT', 
                   'ASSAULT WITH INJURY', 'THEFT', 'CRIMINAL MISCHIEF', 'FAMILY DISTURBANCE', 
                   'BURGLARY OF VEHICLE', 'HARASSMENT'], color ='royalblue', ci=None)
    plt.axvline(clearance_rate, label="Overall Clearance rate", linestyle = '--', alpha=.8, color='orange')
    plt.ylabel('Crime Type', fontsize=13)
    plt.xlabel('Clearance Rate', fontsize=13)
    plt.legend()
    plt.show()

# %%
viz2(top_crimes_df, train)

# %% [markdown]
# **Takeaways:**
# - While DWIs, are the least frequent type of crime reported, they are also the most likely crime to be cleared.
#     - I would think these crimes are actually quite common. I'm surprised they make up such a small percentage but am not surprised they get caught so easily. Drunk driving likely happens very often but is only noticeable when the level of drunkenness is quite high. In those cases when it is noticeable it is very likely to be reported by a bystander and can easily be noticed by a police officer leading to an easy case closure.
# - Theft by shoplifting has a clear rate that is very close to the overall rate of 21%
# - The three top crimes types have very low clear rates. Improvements in clearance rates for these three would significantly improve overall clearance rate.

# %%
plt.title("Relationship Between Crime Clearance Rate and Family Violence", fontsize=20)
sns.barplot(x="crime_type", y="cleared", hue='family_violence', data=top_crimes_df, ci=None)
plt.xticks(rotation = 45) #Rotating the xticks 45 degrees for readability
plt.legend()
plt.show()

# %% [markdown]
# ## Let's explore location_type a bit

# %%
location_type_df = value_counts_and_frequencies(train.location_type)
location_type_df
# Out:
#                                                  count     proba
# RESIDENCE / HOME                                 77791  0.397371
# HWY / ROAD / ALLEY/ STREET/ SIDEWALK             32906  0.168090
# PARKING /DROP LOT/ GARAGE                        25448  0.129993
# OTHER / UNKNOWN                                  14467  0.073900
# COMMERCIAL / OFFICE BUILDING                      5574  0.028473
# HOTEL / MOTEL / ETC.                              4473  0.022849
# DEPARTMENT / DISCOUNT STORE                       4315  0.022042
# RESTAURANT                                        3958  0.020218
# GROCERY / SUPERMARKET                             3390  0.017317
# CONVENIENCE STORE                                 3082  0.015743
# SERVICE/ GAS STATION                              2788  0.014242
# BAR / NIGHTCLUB                                   2283  0.011662
# DRUG STORE / DOCTOR'S OFFICE / HOSPITAL           2269  0.011590
# PARK / PLAYGROUND                                 1717  0.008771
# SPECIALTY  STORE                                  1675  0.008556
# AIR / BUS / TRAIN TERMINAL                        1359  0.006942
# GOVERNMENT / PUBLIC BUILDING                       894  0.004567
# BANK / SAVINGS & LOAN                              878  0.004485
# CONSTRUCTION SITE                                  848  0.004332
# RENTAL STORAGE FACILITY                            811  0.004143
# LIQUOR STORE                                       607  0.003101
# SHOPPING MALL                                      527  0.002692
# AUTO DEALERSHIP NEW / USED                         520  0.002656
# CHURCH / SYNAGOGUE / TEMPLE / MOSQUE               446  0.002278
# SHELTER-MISSION / HOMELESS                         401  0.002048
# ABANDONED/CONDEMNED STRUCTURE                      400  0.002043
# FIELD / WOODS                                      355  0.001813
# SCHOOL - ELEMENTARY / SECONDARY                    298  0.001522
# COMMUNITY CENTER                                   208  0.001063
# SCHOOL - COLLEGE / UNIVERSITY                      176  0.000899
# DAYCARE FACILITY                                   118  0.000603
# SCHOOL / COLLEGE                                   115  0.000587
# CAMP / CAMPGROUND                                  104  0.000531
# JAIL / PRISON/PENITENTIARY/CORRECTIONS FACILITY    103  0.000526
# GAMBLING FACILITY / CASINO / RACE TRACK             79  0.000404
# ATM SEPARATE FROM BANK                              79  0.000404
# CYBERSPACE                                          71  0.000363
# LAKE / WATERWAY/BEACH                               66  0.000337
# INDUSTRIAL SITE                                     52  0.000266
# ARENA / STADIUM / FAIRGROUNDS / COLISEUM            45  0.000230
# AMUSEMENT PARK                                      29  0.000148
# REST AREA                                           23  0.000117
# DOCK / WHARF / FREIGHT / MODAL TERMINAL             12  0.000061
# FARM FACILITY                                        3  0.000015
# MILITARY INSTALLATION                                1  0.000005

# %%
# Let's visualize the top 10 location types
location_type_df['count'].sort_values().tail(10).plot.barh(figsize=(5, 9))
# Out:
# <AxesSubplot:>

# %%
# Create a list with the top 10 locations
top_10_locations = ['RESIDENCE/HOME', 'HWY/ROAD/ALLEY/STREET/SIDEWALK', 'PARKING/DROP LOT/GARAGE', 
                 'OTHER/UNKNOWN', 'COMMERCIAL/OFFICE BUILDING', 'HOTEL/MOTEL/ETC.', 
                 'DEPARTMENT/DISCOUNT STORE', 'RESTAURANT', 'GROCERY/SUPERMARKET',
                 'CONVENIENCE STORE']

# %%
# Creatae a subsetted df that only includes the top 10 crimes
top_locations_df = train.copy()
top_locations_df = top_locations_df[top_locations_df.location_type.isin(top_10_locations)]
top_locations_df.head()
# Out:
#                            crime_type family_violence     occurrence_time  \
# 201179            ASSAULT WITH INJURY               N 2020-04-07 13:48:00
# 162605         BURGLARY NON RESIDENCE               N 2020-08-28 06:04:00
# 315335            BURGLARY OF VEHICLE               N 2019-03-12 22:10:00
# 216368               DEBIT CARD ABUSE               N 2020-02-13 11:34:00
# 55546   BURGLARY OF VEH-NO SUSPECT/FU               N 2021-10-08 17:20:00
#
#        occurrence_date         report_time report_date      location_type  \
# 201179      2020-04-07 2020-04-07 14:12:00  2020-04-07  CONVENIENCE STORE
# 162605      2020-08-28 2020-08-28 06:04:00  2020-08-28         RESTAURANT
# 315335      2019-03-12 2019-03-13 09:51:00  2019-03-13         RESTAURANT
# 216368      2020-02-13 2020-02-13 13:11:00  2020-02-13         RESTAURANT
# 55546       2021-10-08 2021-10-08 19:35:00  2021-10-08         RESTAURANT
#
#                            address  zip_code  council_district sector  \
# 201179           834 E RUNDBERG LN   78753.0               4.0     ED
# 162605            1548 E PARMER LN   78753.0               7.0     ED
# 315335  8565 RESEARCH BLVD SVRD NB   78758.0               4.0     ED
# 216368           9325 N LAMAR BLVD   78753.0               4.0     ED
# 55546        1410 E ANDERSON LN WB   78752.0               4.0     ID
#
#        district   latitude  longitude   clearance_status clearance_date  \
# 201179        7  30.357551 -97.685892  cleared by arrest     2020-04-07
# 162605        6  30.388863 -97.650740        not cleared     2021-05-21
# 315335        2  30.361436 -97.716249        not cleared     2019-03-25
# 216368        1  30.362574 -97.696607        not cleared     2020-02-13
# 55546         2  30.333355 -97.687830        not cleared     2021-11-09
#
#         cleared  time_to_report
# 201179     True 0 days 00:24:00
# 162605    False 0 days 00:00:00
# 315335    False 0 days 11:41:00
# 216368    False 0 days 01:37:00
# 55546     False 0 days 02:15:00

# %%
# Sanity check --- The list didn't work as all the values with slashes are missing
top_locations_df.location_type.value_counts()
# Out:
# RESTAURANT           3958
# CONVENIENCE STORE    3082
# Name: location_type, dtype: int64

# %%
from wrangle import *
df1 = get_crime_data()
df1.info()
# Out:
# Using cached csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 31 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   incident_report_number       500000 non-null  int64
#  1   crime_type                   500000 non-null  object
#  2   ucr_code                     500000 non-null  int64
#  3   family_violence              500000 non-null  object
#  4   occ_date_time                500000 non-null  object
#  5   occ_date                     500000 non-null  object
#  6   occ_time                     500000 non-null  int64
#  7   rep_date_time                500000 non-null  object
#  8   rep_date                     500000 non-null  object
#  9   rep_time                     500000 non-null  int64
#  10  location_type                498336 non-null  object
#  11  address                      500000 non-null  object
#  12  zip_code                     497118 non-null  float64
#  13  council_district             494792 non-null  float64
#  14  sector                       498366 non-null  object
#  15  district                     498224 non-null  object
#  16  pra                          497709 non-null  float64
#  17  census_tract                 495816 non-null  float64
#  18  x_coordinate                 497855 non-null  float64
#  19  y_coordinate                 497855 non-null  float64
#  20  latitude                     490957 non-null  float64
#  21  longitude                    490957 non-null  float64
#  22  location                     490957 non-null  object
#  23  :@computed_region_a3it_2a2z  490952 non-null  float64
#  24  :@computed_region_8spj_utxs  488726 non-null  float64
#  25  :@computed_region_q9nd_rr82  489772 non-null  float64
#  26  ucr_category                 190835 non-null  object
#  27  category_description         190835 non-null  object
#  28  :@computed_region_qwte_z96m  272371 non-null  float64
#  29  clearance_status             440652 non-null  object
#  30  clearance_date               440639 non-null  object
# dtypes: float64(12), int64(4), object(15)
# memory usage: 118.3+ MB
