# %% [markdown]
# # Exploratory Analysis
#
# This notebook contains decisions in the exploratory analysis process of the Austin crime project.
#
# ## The Required Imports
#
# Here we'll import all the modules required to run the code cells in this notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from wrangle import wrangle_crime_data
from prepare import split_data
from explore import *

# %% [markdown]
# ## Acquire and Prepare Data
#
# Here we'll acquire and prepare the data using the wrangle module.

# %%
df = wrangle_crime_data()
df.shape
# Out:
# Using cached csv
# (349581, 17)

# %% [markdown]
# ## Split the Data
#
# Now we will need to split the data before we begin exploring because we will now begin exploring the relationship between the target variable and other features in the data.

# %%
train, validate, test = split_data(df)
train.shape, validate.shape, test.shape
# Out:
# ((195764, 17), (83900, 17), (69917, 17))

# %% [markdown]
# From here on we'll only use the train variable.

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195764 entries, 128272 to 382883
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   crime_type        195764 non-null  object
#  1   family_violence   195764 non-null  object
#  2   occurrence_time   195764 non-null  datetime64[ns]
#  3   occurrence_date   195764 non-null  datetime64[ns]
#  4   report_time       195764 non-null  datetime64[ns]
#  5   report_date       195764 non-null  datetime64[ns]
#  6   location_type     195764 non-null  object
#  7   address           195764 non-null  object
#  8   zip_code          195764 non-null  float64
#  9   council_district  195764 non-null  float64
#  10  sector            195764 non-null  object
#  11  district          195764 non-null  object
#  12  latitude          195764 non-null  float64
#  13  longitude         195764 non-null  float64
#  14  clearance_status  195764 non-null  object
#  15  clearance_date    195764 non-null  datetime64[ns]
#  16  cleared           195764 non-null  bool
# dtypes: bool(1), datetime64[ns](5), float64(4), object(7)
# memory usage: 25.6+ MB

# %% [markdown]
# ## Does the difference between time of incident and report time relate to a crime being solved/closed?
#
# In this notebook we're going to explore the relationship between the clearance status of a case and the difference in time between when the incident occurred and when the incident was reported.
#
# ### Engineer Time Difference Feature
#
# In order to answer this question we will need to create a feature which contains the difference in time between when a crime occurred and when it was reported.

# %%
train['time_to_report'] = train.report_time - train.occurrence_time
train.time_to_report.head()
# Out:
# 128272   0 days 07:16:00
# 420369   0 days 00:00:00
# 79483    1 days 19:54:00
# 430217   6 days 00:00:00
# 280218   0 days 15:34:00
# Name: time_to_report, dtype: timedelta64[ns]

# %% [markdown]
# Now we have the difference between the time when a crime was reported and when it occurred, but we may need to bin this column to help with exploration. There are a lot of unique values in here so in order to gain meaningful insights from this feature we will need to create bins.
#
# ### Binning the Time to Report Column
#
# We'll need to create bins for our data to make exploration easier. We'll create 6 distinct bins: No difference in occurrence and report time, 1 minute - 1 hour, 1 hour - 6 hours, 6 hours - 1 day, 1 day - 1 week, and greater than 1 week.

# %%
train['time_to_report_bins'] = pd.cut(
    train.time_to_report,
    [
        pd.Timedelta('-1d'),
        pd.Timedelta('59s'),
        pd.Timedelta('59m'),
        pd.Timedelta('6h'),
        pd.Timedelta('1d'),
        pd.Timedelta('7d'),
        pd.Timedelta('10y')
    ],
    labels = [
        'No difference',
        '1 minute - 1 hour',
        '1 hour - 6 hours',
        '6 hours - 1 day',
        '1 day - 1 week',
        'Greater than 1 week'
    ]
)
# Out:
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: Units 'M', 'Y' and 'y' do not represent unambiguous timedelta values and will be removed in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
train.time_to_report_bins.value_counts()
# Out:
# No difference          81774
# 6 hours - 1 day        30133
# 1 day - 1 week         28036
# 1 hour - 6 hours       24249
# Greater than 1 week    16245
# 1 minute - 1 hour      15327
# Name: time_to_report_bins, dtype: int64

# %% [markdown]
# ### Visualize the Results

# %%
plt.figure(figsize = (14, 4))

sns.barplot(
    data = train,
    x = 'time_to_report_bins',
    y = 'cleared',
    ci = None
)

plt.xticks(rotation = 15)

plt.xlabel('Time to report')
plt.ylabel('Percentage of cases cleared')

plt.title('The sooner a crime is reported the more likely it is to be solved.');

# %% [markdown]
# #### Takeaways
#
# From the visualization we can determine that the clearance status of a case does depend on the amount time between when the crime occurred and when it was reported. We can verify the significance of this finding with a statistical test.
#
# ### Stats Test
#
# We'll be testing the following hypothesis:
#
# $H_0$: The clearance status of a case is independent of the difference in time between when a crime occurred and when it was reported.
# <br>
# $H_a$: The clearance status of a case is dependent on the difference in time between when a crime occurred and when it was reported.

# %%
chi2(train.time_to_report_bins, train.cleared)
# Out:
# The chi2 value between the two variables is 25046.03220200103 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %% [markdown]
# **Takeaways:**
# <br>
# The results are that we reject the null hypothesis meaning that the clearance status of a case is dependent on the time to report the crime.

# %% [markdown]
# For robustness let's also test this differently:
#
# $H_0$: The average number of cases cleared for cases with time to report less than 6 hours is equal to the average number of cases cleared for cases with time to report greater than 6 hours.
# <br>
# $H_a$: The average number of cases cleared for cases with time to report less than 6 hours is greater than the average number of cases cleared for cases with time to report greater than 6 hours.

# %%
time_to_report_less_than_6hrs = train.time_to_report <= pd.Timedelta('6h')
time_to_report_greater_than_6hrs = train.time_to_report > pd.Timedelta('6h')

t_test_ind(
    train[time_to_report_less_than_6hrs].cleared,
    train[time_to_report_greater_than_6hrs].cleared,
    alternative = 'greater'
)
# Out:
# The t value between the two samples is 162.5 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %% [markdown]
# **Takeaways:**
# <br>
# The results are that we reject the null hypothesis meaning that cases with a time to report less than 6 hours have on average more cleared cases than cases with a time to report greater than 6 hours.

# %% [markdown]
# ## Multivariate Analysis
#
# I'm interested in determining whether or not other variables will have an influence on the dependency between time to report and clearance status. The following variables will be investigated: council district, crime type, and location type.
#
# ### Council District
#
# Let's explore how introducing the council_district feature affects the dependency between time_to_report and clearance_status.

# %%
plt.figure(figsize = (14, 4))

sns.barplot(
    data = train,
    x = 'time_to_report_bins',
    y = 'cleared',
    ci = None,
    hue = 'council_district'
)

plt.xticks(rotation = 15)

plt.xlabel('Time to report')
plt.ylabel('Percentage of cases cleared')

plt.title('Council district does not have a significant impact on the dependency between time to report and clearance status.');

# %% [markdown]
# Let's now verify the significance of this finding with some stats tests. We'll run a test for each council district. The hypotheses will be of the following format:
#
# $H_0$: In council district N the average number of cases cleared for cases with time to report less than 6 hours is equal to the average number of cases cleared for cases with time to report greater than 6 hours.
# <br>
# $H_a$: In council district N the average number of cases cleared for cases with time to report less than 6 hours is greater than the average number of cases cleared for cases with time to report greater than 6 hours.

# %%
time_to_report_less_than_6hrs = train.time_to_report <= pd.Timedelta('6h')
time_to_report_greater_than_6hrs = train.time_to_report > pd.Timedelta('6h')

for council_district in train.council_district.unique():
    print(f'Council District: {council_district}')
    obs_in_council_district_n = train.council_district == council_district
    
    t_test_ind(
        train[time_to_report_less_than_6hrs & obs_in_council_district_n].cleared,
        train[time_to_report_greater_than_6hrs & obs_in_council_district_n].cleared,
        alternative = 'greater'
    )
    print()
# Out:
# Council District: 3.0
# The t value between the two samples is 62.16 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 9.0
# The t value between the two samples is 76.98 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 5.0
# The t value between the two samples is 44.57 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 2.0
# The t value between the two samples is 44.04 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 10.0
# The t value between the two samples is 35.82 and the P-Value is 4.350713002642984e-263.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 1.0
# The t value between the two samples is 49.5 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 7.0
# The t value between the two samples is 55.0 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 8.0
# The t value between the two samples is 32.48 and the P-Value is 2.5535297807051993e-218.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 6.0
# The t value between the two samples is 33.97 and the P-Value is 2.8313481287238403e-241.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: 4.0
# The t value between the two samples is 57.18 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.

# %% [markdown]
# #### Takeaways
#
# The results are that for each council district we reject the null hypothesis meaning that regardless of council district cases with a time to report less than 6 hours on average have more cleared cases than cases with time to report greater than 6 hours.
#
# ### Crime Type
#
# Let's now investigate how crime type affects the dependency between clearance status and time to report.

# %%
# Due to the large number of crime type categories, for exploration purposes we'll use only the top
# 10 crime categories.

top_10_crimes = [
    'DWI',
    'ASSAULT WITH INJURY',
    'THEFT BY SHOPLIFTING',
    'HARASSMENT',
    'AUTO THEFT',
    'ASSAULT W/INJURY-FAM/DATE VIOL',
    'CRIMINAL MISCHIEF',
    'FAMILY DISTURBANCE',
    'THEFT',
    'BURGLARY OF VEHICLE'
]

# Create a subsetted df that only includes the top 10 crimes
top_crimes_df = train.copy()
top_crimes_df = top_crimes_df[top_crimes_df.crime_type.isin(top_10_crimes)]

# %%
plt.figure(figsize = (14, 4))

ax = sns.barplot(
    data = top_crimes_df,
    x = 'time_to_report_bins',
    y = 'cleared',
    ci = None,
    hue = 'crime_type'
)

plt.xticks(rotation = 15)

plt.xlabel('Time to report')
plt.ylabel('Percentage of cases cleared')

plt.title('')

# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# It's a little difficult to see the results for some of these crime types. Let's split these up into different plots.

# %%
fig, ax = plt.subplots(nrows = 10, ncols = 1, figsize = (14, 40))

for index, crime_type in enumerate(top_10_crimes):
    sns.barplot(
        data = train[train.crime_type == crime_type],
        x = 'time_to_report_bins',
        y = 'cleared',
        ci = None,
        ax = ax[index]
    )

    ax[index].set_xlabel('Time to report')
    ax[index].set_ylabel('Percentage of cases cleared')

    ax[index].set_title(crime_type)
    
plt.tight_layout();

# %% [markdown]
# Let's conduct some stats tests to see for how many crime type categories the dependency of clearance status and time to report holds true. We'll test the following hypothesis:
#
# $H_0$: For crime type N the average number of cases cleared for cases with time to report less than 6 hours is equal to the average number of cases cleared for cases with time to report greater than 6 hours.
# <br>
# $H_a$: For crime type N the average number of cases cleared for cases with time to report less than 6 hours is greater than the average number of cases cleared for cases with time to report greater than 6 hours.

# %%
time_to_report_less_than_6hrs = train.time_to_report <= pd.Timedelta('6h')
time_to_report_greater_than_6hrs = train.time_to_report > pd.Timedelta('6h')

for crime_type in train.crime_type.unique():
    print(f'Council District: {crime_type}')
    obs_for_crime_type_n = train.crime_type == crime_type
    
    t_test_ind(
        train[time_to_report_less_than_6hrs & obs_for_crime_type_n].cleared,
        train[time_to_report_greater_than_6hrs & obs_for_crime_type_n].cleared,
        alternative = 'greater'
    )
    print()
# Out:
# Council District: IDENTITY THEFT
# The t value between the two samples is 7.268 and the P-Value is 2.2508509373393677e-13.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: POSS CONTROLLED SUB/NARCOTIC
# The t value between the two samples is 1.128 and the P-Value is 0.12980085548782286.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BURGLARY OF VEHICLE
# The t value between the two samples is 27.3 and the P-Value is 2.5617051792554787e-161.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: INTERFERENCE PUBLIC DUTIES
# The t value between the two samples is -0.5794 and the P-Value is 0.7171801419052835.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRASH/FAIL STOP AND RENDER AID
# The t value between the two samples is 2.783 and the P-Value is 0.002728291773727311.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CRIMINAL MISCHIEF
# The t value between the two samples is 20.74 and the P-Value is 5.014417536680577e-94.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: PUBLIC INTOXICATION
# The t value between the two samples is 1.036 and the P-Value is 0.15022817405970823.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG ASLT STRANGLE/SUFFOCATE
# The t value between the two samples is 9.85 and the P-Value is 1.9875865805455622e-22.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT
# The t value between the two samples is 49.02 and the P-Value is 0.0.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CRED CARD ABUSE - OTHER
# The t value between the two samples is 8.887 and the P-Value is 7.638841868312469e-19.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: ASSAULT BY CONTACT FAM/DATING
# The t value between the two samples is 2.461 and the P-Value is 0.006972084062451148.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: FAMILY DISTURBANCE
# The t value between the two samples is 1.343 and the P-Value is 0.08966398018656631.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSSESSION OF MARIJUANA
# The t value between the two samples is 2.376 and the P-Value is 0.00879922009408604.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: AGG ROBBERY/DEADLY WEAPON
# The t value between the two samples is 3.489 and the P-Value is 0.0002507000740713185.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: BURGLARY OF SHED/DETACHED GARAGE/STORAGE UNIT
# The t value between the two samples is 2.795 and the P-Value is 0.0026368925721834994.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: AUTO THEFT
# The t value between the two samples is 6.438 and the P-Value is 6.46355111608205e-11.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT FROM BUILDING
# The t value between the two samples is -0.9889 and the P-Value is 0.8384457654480078.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT WITH INJURY
# The t value between the two samples is 4.318 and the P-Value is 8.021250442494193e-06.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DISTURBANCE - OTHER
# The t value between the two samples is 1.211 and the P-Value is 0.11297275721136955.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT W/INJURY-FAM/DATE VIOL
# The t value between the two samples is 17.31 and the P-Value is 4.4778008111552017e-66.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DWI
# The t value between the two samples is 0.8033 and the P-Value is 0.2109107188478465.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: HARASSMENT
# The t value between the two samples is 2.198 and the P-Value is 0.014008977932411392.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT OF BICYCLE
# The t value between the two samples is 7.654 and the P-Value is 1.295264605016265e-14.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: ASSAULT BY CONTACT
# The t value between the two samples is 6.641 and the P-Value is 1.777551776565964e-11.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DATING DISTURBANCE
# The t value between the two samples is 0.6947 and the P-Value is 0.24368588641610273.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CUSTODY ARREST TRAFFIC WARR
# The t value between the two samples is -0.2225 and the P-Value is 0.5879771188633545.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BREACH OF COMPUTER SECURITY
# The t value between the two samples is 2.144 and the P-Value is 0.016466500730686385.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT BY SHOPLIFTING
# The t value between the two samples is 32.93 and the P-Value is 3.157245821628049e-218.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: HARASSMENT OF A PUBLIC SERVANT
# The t value between the two samples is 3.206 and the P-Value is 0.0008477874652669579.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: POSS OF DRUG PARAPHERNALIA
# The t value between the two samples is 3.021 and the P-Value is 0.001278460483440419.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: RECKLESS DAMAGE
# The t value between the two samples is 2.364 and the P-Value is 0.009485200494476922.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CRIMINAL TRESPASS
# The t value between the two samples is 13.45 and the P-Value is 1.3536835441815918e-40.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: BURGLARY OF RESIDENCE
# The t value between the two samples is 10.53 and the P-Value is 6.245408836056336e-26.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: GRAFFITI
# The t value between the two samples is 5.424 and the P-Value is 4.489153867363624e-08.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DOC DISCHARGE GUN - PUB PLACE
# The t value between the two samples is 0.5485 and the P-Value is 0.2918789604191566.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: PROSTITUTION
# The t value between the two samples is 0.2275 and the P-Value is 0.41029246102449807.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BURGLARY NON RESIDENCE
# The t value between the two samples is 10.59 and the P-Value is 3.616420264820723e-26.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: FRAUD DESTRUCTION OF A WRITING
# The t value between the two samples is 2.405 and the P-Value is 0.011654389750040399.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: POCKET PICKING
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FRAUD - OTHER
# The t value between the two samples is 11.87 and the P-Value is 5.220134669936357e-32.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: FAMILY DISTURBANCE/PARENTAL
# The t value between the two samples is 0.6115 and the P-Value is 0.270509217821313.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: IMPERSONATING PUBLIC SERVANT
# The t value between the two samples is 1.254 and the P-Value is 0.11157911749842683.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INJURY TO CHILD
# The t value between the two samples is 0.8135 and the P-Value is 0.2084580745894774.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRUELTY TO ANIMALS
# The t value between the two samples is 3.411 and the P-Value is 0.0003551983324112401.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: TERRORISTIC THREAT-FAM/DAT VIO
# The t value between the two samples is 1.656 and the P-Value is 0.04924891774202089.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: BURG OF RES - FAM/DATING ASLT
# The t value between the two samples is -0.8516 and the P-Value is 0.8017276845408261.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: PROTECTIVE ORDER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FELONY ENHANCEMENT/ASSLT W/INJ
# The t value between the two samples is 5.419 and the P-Value is 4.5690233751007786e-08.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DEL CONTROLLED SUB/NARCOTIC
# The t value between the two samples is 0.2789 and the P-Value is 0.3902333076623645.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC FIGHTING
# The t value between the two samples is 1.052 and the P-Value is 0.14680105787900588.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: THEFT-NO SUSPECT/FOLLOWUP
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FORGERY AND PASSING
# The t value between the two samples is 8.932 and the P-Value is 7.657899740947644e-19.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: AGG ASLT ENHANC STRANGL/SUFFOC
# The t value between the two samples is 0.1423 and the P-Value is 0.44353002255373025.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ROBBERY BY ASSAULT
# The t value between the two samples is 3.783 and the P-Value is 8.405430232782812e-05.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: ASSAULT BY THREAT
# The t value between the two samples is 3.679 and the P-Value is 0.00011981656949299795.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: UNLAWFUL CARRYING WEAPON
# The t value between the two samples is 0.1479 and the P-Value is 0.4412295888597014.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: RUNAWAY CHILD
# The t value between the two samples is -0.2986 and the P-Value is 0.6173832426997203.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DWI 2ND
# The t value between the two samples is -0.2813 and the P-Value is 0.6107132688641039.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DEBIT CARD ABUSE
# The t value between the two samples is 1.364 and the P-Value is 0.08643181532477118.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: EVADING / FOOT
# The t value between the two samples is 1.552 and the P-Value is 0.060777540427955946.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: EVADING VEHICLE
# The t value between the two samples is -0.3972 and the P-Value is 0.6543021048119966.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC EXPOSURE
# The t value between the two samples is 5.865 and the P-Value is 9.012030565806393e-09.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT FROM PERSON
# The t value between the two samples is 8.766 and the P-Value is 3.475981071325123e-18.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT OF AUTO PARTS
# The t value between the two samples is 1.205 and the P-Value is 0.11443391264793296.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BURGLARY OF VEH-NO SUSPECT/FU
# The t value between the two samples is -0.8145 and the P-Value is 0.792298553760289.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG ASSAULT
# The t value between the two samples is 4.971 and the P-Value is 3.607907361110409e-07.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: VIOL OF PROTECTIVE ORDER
# The t value between the two samples is 5.638 and the P-Value is 1.1897338053859107e-08.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: INJURY TO ELDERLY PERSON
# The t value between the two samples is 1.958 and the P-Value is 0.02616862042287649.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: VIOL CITY ORDINANCE - DOG
# The t value between the two samples is 1.199 and the P-Value is 0.1170224367029971.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: THEFT OF SERVICE
# The t value between the two samples is 12.06 and the P-Value is 1.2239425415272083e-31.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: WARRANT ARREST NON TRAFFIC
# The t value between the two samples is 0.6921 and the P-Value is 0.2445177700443258.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: MAIL THEFT
# The t value between the two samples is 12.15 and the P-Value is 7.757546096655151e-33.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CRED CARD ABUSE BY FORGERY
# The t value between the two samples is 3.644 and the P-Value is 0.00018969831340657844.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT CATALYTIC CONVERTER
# The t value between the two samples is 3.222 and the P-Value is 0.0006530636802679117.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CHILD CUSTODY INTERFERE
# The t value between the two samples is 0.1645 and the P-Value is 0.4346820187193724.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: RENTAL CAR/FAIL TO RETURN
# The t value between the two samples is -1.713 and the P-Value is 0.95521049666842.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TERRORISTIC THREAT
# The t value between the two samples is 7.137 and the P-Value is 7.374588602930223e-13.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CRIMINAL MISCHIEF-NO SUSPECT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AIRPORT - CRIMINAL TRESPASS
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DEADLY CONDUCT
# The t value between the two samples is 3.117 and the P-Value is 0.000962526032774651.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: VIOL CITY ORDINANCE - WRECKER
# The t value between the two samples is 1.331 and the P-Value is 0.0922847423816958.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INDECENT EXPOSURE
# The t value between the two samples is 2.721 and the P-Value is 0.00339727497300707.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: POSS DANG DRUG
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: RESISTING ARREST OR SEARCH
# The t value between the two samples is -0.4584 and the P-Value is 0.676421497265719.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG ASSAULT FAM/DATE VIOLENCE
# The t value between the two samples is 7.171 and the P-Value is 7.826215278839794e-13.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: TAMPERING WITH EVIDENCE
# The t value between the two samples is 1.786 and the P-Value is 0.04067446645697767.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DWI  .15 BAC OR ABOVE
# The t value between the two samples is -0.3602 and the P-Value is 0.6406100729598255.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DAMAGE CITY PROP
# The t value between the two samples is 1.33 and the P-Value is 0.09244272706291104.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: THEFT OF LICENSE PLATE
# The t value between the two samples is 2.136 and the P-Value is 0.01641816614851735.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: VIOL OF EMERG PROTECTIVE ORDER
# The t value between the two samples is 1.4 and the P-Value is 0.08107989397361978.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: COUNTERFEITING
# The t value between the two samples is 1.361 and the P-Value is 0.0876962345963191.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DRIVING WHILE INTOX / FELONY
# The t value between the two samples is 7.25 and the P-Value is 8.335966625510821e-13.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT- APPROPRIATE STOLEN PROP
# The t value between the two samples is 2.018 and the P-Value is 0.028980942134789855.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: AGG ASLT W/MOTOR VEH FAM/DAT V
# The t value between the two samples is 0.7104 and the P-Value is 0.24005099833493931.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSS OF FIREARM BY FELON
# The t value between the two samples is 3.214 and the P-Value is 0.0007192806629228322.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: EXPLOSIVE ORDNANCE DISPOSAL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ARSON
# The t value between the two samples is 1.609 and the P-Value is 0.05468198367110978.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSS SYNTHETIC MARIJUANA
# The t value between the two samples is -0.3527 and the P-Value is 0.6375584781065631.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL CITY ORDINANCE - OTHER
# The t value between the two samples is 2.167 and the P-Value is 0.01574647941295061.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: FORGERY BY ALTERATION
# The t value between the two samples is 0.9659 and the P-Value is 0.16995135535228362.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT ON PUBLIC SERVANT
# The t value between the two samples is 1.314 and the P-Value is 0.09510848932904827.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: EVADING / VEHICLE PURSUIT
# The t value between the two samples is -1.483 and the P-Value is 0.9300391799184218.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: THEFT FROM AUTO
# The t value between the two samples is 1.129 and the P-Value is 0.12961297041980088.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG ASSAULT ON PUBLIC SERVANT
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /opt/homebrew/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSS CONTROLLED SUB/SYN NARC
# The t value between the two samples is -0.6678 and the P-Value is 0.747280383895427.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC ABUSE OR THREAT
# The t value between the two samples is 0.504 and the P-Value is 0.31058142834464675.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSS OF PROHIBITED WEAPON
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DWI - CHILD PASSENGER
# The t value between the two samples is -0.1475 and the P-Value is 0.5584522428062502.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BURGLARY OF COIN-OP MACHINE
# The t value between the two samples is 4.086 and the P-Value is 4.1533377012850826e-05.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: CRIMINAL TRESPASS/TRANSIENT
# The t value between the two samples is 1.523 and the P-Value is 0.06411921013944032.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FAILURE TO IDENTIFY
# The t value between the two samples is 3.804 and the P-Value is 8.121548774914956e-05.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: FORGERY - OTHER
# The t value between the two samples is 4.125 and the P-Value is 3.0964991657262914e-05.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT OF METAL
# The t value between the two samples is 5.986 and the P-Value is 7.611995082529261e-09.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT OF TRAILER
# The t value between the two samples is 3.324 and the P-Value is 0.00047434780528407756.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: INTER EMERG PHONECALL FAM/DATE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRIMINAL TRESPASS/IN VEHICLE
# The t value between the two samples is 1.119 and the P-Value is 0.13330123359978083.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC WINDOW PEEPING-RESIDENCE
# The t value between the two samples is 1.605 and the P-Value is 0.05620021270289824.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: LIQUOR LAW VIOLATION/OTHER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: PAROLE VIOL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT OF PREGNANT WM-FAM/DAT
# The t value between the two samples is -0.6563 and the P-Value is 0.7430905894773256.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL STATE LAW - OTHER
# The t value between the two samples is 4.488 and the P-Value is 7.019425420743765e-06.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: STALKING
# The t value between the two samples is 1.409 and the P-Value is 0.0805947254370501.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VOCO - ALCOHOL  CONSUMPTION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FORGERY BY MAKING
# The t value between the two samples is -0.481 and the P-Value is 0.6841372358567819.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INJURY TO CHILD (CARE/CUSTODY)
# The t value between the two samples is 0.772 and the P-Value is 0.22316572087290537.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: THEFT OF HEAVY EQUIPMENT
# The t value between the two samples is -0.529 and the P-Value is 0.699877012177544.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DAMAGE CITY VEHICLE
# The t value between the two samples is 1.346 and the P-Value is 0.08984997076493621.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AIRPORT PLACES WEAPON PROHIBIT
# The t value between the two samples is -0.2294 and the P-Value is 0.5906177660477058.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT BY THREAT FAM/DATING
# The t value between the two samples is -0.03012 and the P-Value is 0.5120089060941163.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ONLINE IMPERSONATION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FALSE ALARM OR REPORT
# The t value between the two samples is 0.8802 and the P-Value is 0.19051142463621445.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FRAUD-CARD SKIMMER
# The t value between the two samples is 0.5078 and the P-Value is 0.3062234721424986.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DWI - DRUG RECOGNITION EXPERT
# The t value between the two samples is 2.575 and the P-Value is 0.0053699546805860785.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: THEFT BY EXTORTION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC ABUSIVE LANGUAGE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FALSE REPORT TO PEACE OFFICER
# The t value between the two samples is -1.539 and the P-Value is 0.9362588572127079.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG ASSAULT WITH MOTOR VEH
# The t value between the two samples is 1.055 and the P-Value is 0.14680176348783824.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT ON PEACE OFFICER
# The t value between the two samples is 9.173 and the P-Value is 8.498087481679658e-16.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DOC DISPLAY GUN/DEADLY PUB PLC
# The t value between the two samples is 0.763 and the P-Value is 0.22319104018092373.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: PROBATION VIOL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TAKE WEAPON FRM POLICE OFFICER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: HINDERING APPREHENSION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ROBBERY BY THREAT
# The t value between the two samples is 3.036 and the P-Value is 0.0013499737256193133.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: TOBACCO VIOL - UNDER AGE 17
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRIMINAL TRESPASS/HOTEL
# The t value between the two samples is 1.04 and the P-Value is 0.15011050959628247.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: HARBORING RUNAWAY CHILD
# The t value between the two samples is 0.6642 and the P-Value is 0.2583180438465368.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FEDERAL VIOL/OTHER
# The t value between the two samples is 2.508 and the P-Value is 0.007561812595120184.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: DISRUPTING MEETING/PROCESSION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC DISCHARGE GUN - PUB ROAD
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INTERFERING W/EMERG PHONE CALL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DUMPING REFUSE NEAR HIGHWAY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: EXPLOITATION OF CHILD/ELDERLY
# The t value between the two samples is -3.0 and the P-Value is 0.9961572939298429.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRASH/MANSLAUGHTER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: UNLAWFUL RESTRAINT FAM/DAT VIO
# The t value between the two samples is 1.735 and the P-Value is 0.044247227123902014.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: VIOL OF CAMPING ORDINANCE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSS CONTROLLED SUB/OTHER
# The t value between the two samples is -0.4756 and the P-Value is 0.6824338054921868.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL TEMP EX PARTE  ORDER
# The t value between the two samples is 0.7533 and the P-Value is 0.228663913975497.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: NUISANCE ABATEMENT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: PUBLIC INTOX-SOBERING CENTER
# The t value between the two samples is -0.4779 and the P-Value is 0.6833901432390466.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DISTRIB HARMFUL MATERIAL MINOR
# The t value between the two samples is 0.06228 and the P-Value is 0.47551149581233804.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TAMPERING WITH CONSUMER PROD
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INDECENT ASSAULT
# The t value between the two samples is 0.8594 and the P-Value is 0.19584401090234005.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: PURSE SNATCHING
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DUI - AGE 17 TO 20
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TERRORISTIC THREAT-MASS CASLTY
# The t value between the two samples is 0.1089 and the P-Value is 0.4570020552838973.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CHILD ENDANGERMENT- ABANDONMEN
# The t value between the two samples is 1.754 and the P-Value is 0.04077695563359284.
# ----------------------------------------------------------------------------
# Since the P value is less than the alpha, we reject the null hypothesis.
#
# Council District: LITTERING
# The t value between the two samples is 1.148 and the P-Value is 0.131073098197214.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DEL MARIJUANA
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DEADLY CONDUCT FAM/DATE VIOL
# The t value between the two samples is 1.409 and the P-Value is 0.08961316916775838.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: LOCATION RESTRICT KNIFE CLS C
# The t value between the two samples is nan and the P-Value is nan.
# ...
#
# Council District: OBSCENE DISPLAY - DISTRIBUTION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: RIOT
# The t value between the two samples is 0.0 and the P-Value is 0.5.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FIREARMS ON SCHOOL PROP
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VOCO AMPLIFIED MUSIC/VEHICLE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TELECOMMUNICATION CRIMES/OTHER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DANG DRUG VIOL - OTHER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRIMINAL CONSPIRACY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: COMMERCIAL BRIBERY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VOYEURISM-PEEPING TOM
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG ASSAULT BY PUBLIC SERVANT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: STAY AWAY ORDER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BESTIALITY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: IMMIGRATION HOLD/ARREST
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DEL CONTROLLED SUB/OTHER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INTERFERE W PO SERVICE ANIMALS
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: SIT AND LIE ORDINANCE VIOL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL CITY ORDINANCE -FIREWORK
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL OF PARK CURFEW
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: GAMBLING PROMOTION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: MANSLAUGHTER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DUI - AGE 16 AND UNDER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRASH/CRIM NEG HOMICIDE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG KIDNAPPING FAM VIO
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AGG KIDNAPPING
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: MANF CONTROLLED SUB- SYN NARC
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BANK KITING
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: INJURY TO ELDERLY PERSON - SBI
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TOBACCO VIOL - UNDER AGE 21
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ATT AUTO THEFT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: MAKING TOBACCO AVAIL TO MINOR
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FALSE ID AS A PEACE OFFICER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC CREATING NOXIOUS ODOR
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: POSS OF PRESCRIPTION FORM
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FICTITIOUS NAME
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL OF OBSTRUCTION ORDINANCE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AIRPORT - BREACH OF SECURITY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ASSAULT - SCHOOL PERSONNEL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: RECKLESS CONDUCT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: TRUANCY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FALSE CALLER ID DISPLAY/SPOOF
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FAIL TO REGISTER - ADULT VIC
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BOATING WHILE INTOXICATED
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: THEFT OF TELECOMMUNICATION SRV
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DEL OF ALCOHOL TO MINOR
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BRIBERY
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DOC WINDOW PEEPING - HOTEL
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: DISRUPTIVE ACTS AT SCHOOLS
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VOCO SOLICITATION PROHIBIT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: AIRPORT - BOMB THREAT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: OFFICIAL MISCONDUCT
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: HARASSMENT ONLINE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: ATT BURGLARY OF RESIDENCE
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRIMINAL SOLICITATION
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: MANF CONTROLLED SUB - OTHER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: FALSE REPORT TO CPS
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: MANF SYNTHETIC MARIJUANA
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: CRIM NEG HOMICIDE/NON TRAFFIC
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: VIOL STAY AWAY ORDER
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.
#
# Council District: BAIL JUMPING/FAIL TO APPEAR
# The t value between the two samples is nan and the P-Value is nan.
# ----------------------------------------------------------------------------
# Since the P value is greater than the alpha, we fail to reject the null hypothesis.

# %% [markdown]
# #### Takeaways
#
# For the most part, each crime type follows the same pattern where the average number of cases solved decreases as time to report increases with two exceptions. DWI cases seem to always get cleared regardless of time to report. Family disturbance cases are much more sporadic with large percentages of solved cases for time to report of 1 hour - 6 hours and greater than 1 week.
